# %% [markdown]
# <a href="https://colab.research.google.com/github/noushsuon/honours-project/blob/main/DistilBERT-Base-Cased.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets
# !pip install evaluate
# !pip install accelerate -U
# !pip install comet_ml

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import comet_ml
from comet_ml import Experiment
from transformers import AutoModelForSequenceClassification, Trainer, TrainingArguments

experiment = Experiment(api_key="uyaIbaxDfy7jK9j7u4KNxeKNg",project_name="Honours",)
comet_ml.init(api_key='uyaIbaxDfy7jK9j7u4KNxeKNg',project_name='comet-bert-experiment')
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# [codecarbon INFO @ 16:09:52] [setup] RAM Tracking...
# [codecarbon INFO @ 16:09:52] [setup] GPU Tracking...
# [codecarbon INFO @ 16:09:52] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:09:52] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:09:52] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon WARNING @ 16:09:53] We saw that you have a 13th Gen Intel(R) Core(TM) i9-13950HX but we don't know it. Please contact us.
# [codecarbon INFO @ 16:09:53] CPU Model on constant consumption mode: 13th Gen Intel(R) Core(TM) i9-13950HX
# [codecarbon INFO @ 16:09:53] >>> Tracker's metadata:
# [codecarbon INFO @ 16:09:53]   Platform system: Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:09:53]   Python version: 3.10.12
# [codecarbon INFO @ 16:09:53]   CodeCarbon version: 2.3.4
# [codecarbon INFO @ 16:09:53]   Available RAM : 15.439 GB
# [codecarbon INFO @ 16:09:53]   CPU count: 32
# [codecarbon INFO @ 16:09:53]   CPU model: 13th Gen Intel(R) Core(TM) i9-13950HX
# [codecarbon INFO @ 16:09:53]   GPU count: 1
# [codecarbon INFO @ 16:09:53]   GPU model: 1 x NVIDIA GeForce RTX 4090 Laptop GPU
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/noushsuon/honours/817e9783f154481cadb36b4f7defc352
#
# COMET INFO: Valid Comet API Key saved in /root/.comet.config (set COMET_CONFIG to change where it is saved).

# %%
from datasets import load_dataset
from transformers import AutoTokenizer

model_checkpoint = "distilbert-base-cased"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

raw_datasets = load_dataset("squad")
raw_datasets
# Out:
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 87599
#     })
#     validation: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 10570
#     })
# })

# %%
context = raw_datasets["train"][0]["context"]
question = raw_datasets["train"][0]["question"]

inputs = tokenizer(question, context)
tokenizer.decode(inputs["input_ids"])
# Out:
# '[CLS] To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France? [SEP] Architecturally, the school has a Catholic character. Atop the Main Building\'s gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend " Venite Ad Me Omnes ". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive ( and in a direct line that connects through 3 statues and the Gold Dome ), is a simple, modern stone statue of Mary. [SEP]'

# %%
max_length = 384
stride = 128


def preprocess_training_examples(examples):
    questions = [q.strip() for q in examples["question"]]
    inputs = tokenizer(
        questions,
        examples["context"],
        max_length=max_length,
        truncation="only_second", #only truncates the context
        stride=stride,
        return_overflowing_tokens=True, #model will store strings ignored when truncating
        return_offsets_mapping=True, #stores the location of tokens in original text
        padding="max_length",
    )

    offset_mapping = inputs.pop("offset_mapping")
    sample_map = inputs.pop("overflow_to_sample_mapping")
    answers = examples["answers"]
    start_positions = []
    end_positions = []

    for i, offset in enumerate(offset_mapping):
        sample_idx = sample_map[i]
        answer = answers[sample_idx]
        start_char = answer["answer_start"][0]
        end_char = answer["answer_start"][0] + len(answer["text"][0])
        sequence_ids = inputs.sequence_ids(i)

        # Find the start and end of the context
        idx = 0
        while sequence_ids[idx] != 1:
            idx += 1
        context_start = idx
        while sequence_ids[idx] == 1:
            idx += 1
        context_end = idx - 1

        # If the answer is not fully inside the context, label is (0, 0)
        if offset[context_start][0] > start_char or offset[context_end][1] < end_char:
            start_positions.append(0)
            end_positions.append(0)
        else:
            # Otherwise it's the start and end token positions
            idx = context_start
            while idx <= context_end and offset[idx][0] <= start_char:
                idx += 1
            start_positions.append(idx - 1)

            idx = context_end
            while idx >= context_start and offset[idx][1] >= end_char:
                idx -= 1
            end_positions.append(idx + 1)

    inputs["start_positions"] = start_positions
    inputs["end_positions"] = end_positions
    return inputs

# %%
#use previously defined function to preprocess training data
train_dataset = raw_datasets["train"].map(
    preprocess_training_examples,
    batched=True,
    remove_columns=raw_datasets["train"].column_names,
)
len(raw_datasets["train"]), len(train_dataset) #check the sentences have been tokenised
# Out:
# Map:   0%|          | 0/87599 [00:00<?, ? examples/s]
# [codecarbon INFO @ 16:10:08] Energy consumed for RAM : 0.000024 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:10:08] Energy consumed for all GPUs : 0.000029 kWh. Total GPU Power : 7.0319697589832435 W
# [codecarbon INFO @ 16:10:08] Energy consumed for all CPUs : 0.000177 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:10:08] 0.000231 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:10:23] Energy consumed for RAM : 0.000048 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:10:23] Energy consumed for all GPUs : 0.000062 kWh. Total GPU Power : 7.890470084243406 W
# [codecarbon INFO @ 16:10:23] Energy consumed for all CPUs : 0.000354 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:10:23] 0.000465 kWh of electricity used since the beginning.
# (87599, 88729)

# %%
'''
similar to training data except
  -without start and end positions
  -simplified offset mapping
  -uses example ids
'''
def preprocess_validation_examples(examples):
    questions = [q.strip() for q in examples["question"]]
    inputs = tokenizer(
        questions,
        examples["context"],
        max_length=max_length,
        truncation="only_second",
        stride=stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    sample_map = inputs.pop("overflow_to_sample_mapping")
    example_ids = []

    for i in range(len(inputs["input_ids"])):
        sample_idx = sample_map[i]
        example_ids.append(examples["id"][sample_idx])

        sequence_ids = inputs.sequence_ids(i)
        offset = inputs["offset_mapping"][i]
        inputs["offset_mapping"][i] = [
            o if sequence_ids[k] == 1 else None for k, o in enumerate(offset)
        ]

    inputs["example_id"] = example_ids
    return inputs

# %%
#use function to preprocess validation data
validation_dataset = raw_datasets["validation"].map(
    preprocess_validation_examples,
    batched=True,
    remove_columns=raw_datasets["validation"].column_names,
)
len(raw_datasets["validation"]), len(validation_dataset)
# Out:
# Map:   0%|          | 0/10570 [00:00<?, ? examples/s]
# (10570, 10822)

# %% [markdown]
# post processing

# %%
start_logits = outputs.start_logits.cpu().numpy()
end_logits = outputs.end_logits.cpu().numpy()

# %%
import evaluate
metric = evaluate.load("squad")

# %%
from tqdm.auto import tqdm
import collections
import numpy as np

n_best = 20
max_answer_length = 30
predicted_answers = []

def get_example(index):
    return tokenized_datasets["test"][index]["text"]

def compute_metrics(start_logits, end_logits, features, examples):
    experiment = comet_ml.get_global_experiment()
    example_to_features = collections.defaultdict(list)

    for idx, feature in enumerate(features):
        example_to_features[feature["example_id"]].append(idx)

    predicted_answers = []

    for example in tqdm(examples):
        example_id = example["id"]
        context = example["context"]
        answers = []

        # Loop through all features associated with that example
        for feature_index in example_to_features[example_id]:
            start_logit = start_logits[feature_index]
            end_logit = end_logits[feature_index]
            offsets = features[feature_index]["offset_mapping"]

            start_indexes = np.argsort(start_logit)[-1 : -n_best - 1 : -1].tolist()
            end_indexes = np.argsort(end_logit)[-1 : -n_best - 1 : -1].tolist()
            for start_index in start_indexes:
                for end_index in end_indexes:
                    # Skip answers that are not fully in the context
                    if offsets[start_index] is None or offsets[end_index] is None:
                        continue
                    # Skip answers with a length that is either < 0 or > max_answer_length
                    if (
                        end_index < start_index
                        or end_index - start_index + 1 > max_answer_length
                    ):
                        continue

                    answer = {
                        "text": context[offsets[start_index][0] : offsets[end_index][1]],
                        "logit_score": start_logit[start_index] + end_logit[end_index],
                    }
                    answers.append(answer)

        # Select the answer with the best score
        if len(answers) > 0:
            best_answer = max(answers, key=lambda x: x["logit_score"])
            predicted_answers.append(
                {"id": example_id, "prediction_text": best_answer["text"]}
            )
        else:
            predicted_answers.append({"id": example_id, "prediction_text": ""})

    theoretical_answers = [{"id": ex["id"], "answers": ex["answers"]} for ex in examples
    ]
    metric_result = metric.compute(predictions=predicted_answers, references=theoretical_answers)
    if experiment:
        #experiment.set_epoch(epoch)
        experiment.log_metric("f1", metric_result['f1'])
        experiment.log_metric("exact_match", metric_result['exact_match'])
    return metric_result

# %%
model = AutoModelForQuestionAnswering.from_pretrained(model_checkpoint)
# Out:
# model.safetensors:   0%|          | 0.00/263M [00:00<?, ?B/s]
# Some weights of DistilBertForQuestionAnswering were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import transformers
from transformers import TrainingArguments
import accelerate

# %env COMET_MODE=ONLINE
# %env COMET_LOG_ASSETS=TRUE

args = TrainingArguments(
    "bert-finetuned-squad",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_steps=100,
    fp16=True,
    push_to_hub=True,
    report_to=["comet_ml"],
    logging_strategy="epoch",
    seed=42,
    load_best_model_at_end=False,
    save_total_limit=1,
)
# Out:
# env: COMET_MODE=ONLINE
# env: COMET_LOG_ASSETS=TRUE

# %%
from transformers import Trainer
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=validation_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
# [codecarbon INFO @ 16:10:53] Energy consumed for RAM : 0.000095 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:10:53] Energy consumed for all GPUs : 0.000163 kWh. Total GPU Power : 11.933847764351338 W
# [codecarbon INFO @ 16:10:53] Energy consumed for all CPUs : 0.000702 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:10:53] 0.000960 kWh of electricity used since the beginning.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/noushsuon/honours/817e9783f154481cadb36b4f7defc352
# COMET INFO:   Metrics:
# COMET INFO:     exact_match : 83.0
# COMET INFO:     f1          : 88.25000000000004
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 1 (840 bytes)
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# [codecarbon INFO @ 16:10:55] [setup] RAM Tracking...
# [codecarbon INFO @ 16:10:55] [setup] GPU Tracking...
# [codecarbon INFO @ 16:10:55] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 16:10:55] [setup] CPU Tracking...
# [codecarbon WARNING @ 16:10:55] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon WARNING @ 16:10:56] We saw that you have a 13th Gen Intel(R) Core(TM) i9-13950HX but we don't know it. Please contact us.
# [codecarbon INFO @ 16:10:56] CPU Model on constant consumption mode: 13th Gen Intel(R) Core(TM) i9-13950HX
# [codecarbon INFO @ 16:10:56] >>> Tracker's metadata:
# [codecarbon INFO @ 16:10:56]   Platform system: Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 16:10:56]   Python version: 3.10.12
# [codecarbon INFO @ 16:10:56]   CodeCarbon version: 2.3.4
# [codecarbon INFO @ 16:10:56]   Available RAM : 15.439 GB
# [codecarbon INFO @ 16:10:56]   CPU count: 32
# [codecarbon INFO @ 16:10:56]   CPU model: 13th Gen Intel(R) Core(TM) i9-13950HX
# [codecarbon INFO @ 16:10:56]   GPU count: 1
# [codecarbon INFO @ 16:10:56]   GPU model: 1 x NVIDIA GeForce RTX 4090 Laptop GPU
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/noushsuon/comet-bert-experiment/1692597ec018440ca8f5deaf2d5e3026
#     <div>
#
#       <progress value='33276' max='33276' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [33276/33276 31:42, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.539000</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.931800</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.685500</td>
#       <td>No log</td>
#     </tr>
#   </tbody>
# </table><p>
# [codecarbon INFO @ 16:11:11] Energy consumed for RAM : 0.000024 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:11:11] Energy consumed for all GPUs : 0.000437 kWh. Total GPU Power : 104.85178870810745 W
# [codecarbon INFO @ 16:11:11] Energy consumed for all CPUs : 0.000177 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:11:11] 0.000638 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:11:26] Energy consumed for RAM : 0.000048 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:11:26] Energy consumed for all GPUs : 0.000917 kWh. Total GPU Power : 115.2577696265542 W
# [codecarbon INFO @ 16:11:26] Energy consumed for all CPUs : 0.000354 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:11:26] 0.001319 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:11:41] Energy consumed for RAM : 0.000072 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:11:41] Energy consumed for all GPUs : 0.001404 kWh. Total GPU Power : 116.94816881133951 W
# [codecarbon INFO @ 16:11:41] Energy consumed for all CPUs : 0.000531 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:11:41] 0.002008 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:11:56] Energy consumed for RAM : 0.000096 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:11:56] Energy consumed for all GPUs : 0.001887 kWh. Total GPU Power : 115.88607777413618 W
# [codecarbon INFO @ 16:11:56] Energy consumed for all CPUs : 0.000708 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:11:56] 0.002691 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:12:11] Energy consumed for RAM : 0.000121 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:12:12] Energy consumed for all GPUs : 0.002374 kWh. Total GPU Power : 116.89309187390748 W
# [codecarbon INFO @ 16:12:12] Energy consumed for all CPUs : 0.000886 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:12:12] 0.003380 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:12:26] Energy consumed for RAM : 0.000145 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:12:27] Energy consumed for all GPUs : 0.002857 kWh. Total GPU Power : 115.84329236839827 W
# [codecarbon INFO @ 16:12:27] Energy consumed for all CPUs : 0.001063 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:12:27] 0.004064 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:12:41] Energy consumed for RAM : 0.000169 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:12:41] Energy consumed for all GPUs : 0.003337 kWh. Total GPU Power : 115.34558971744052 W
# [codecarbon INFO @ 16:12:41] Energy consumed for all CPUs : 0.001240 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:12:42] 0.004745 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:12:56] Energy consumed for RAM : 0.000193 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:12:56] Energy consumed for all GPUs : 0.003822 kWh. Total GPU Power : 116.4189761726581 W
# [codecarbon INFO @ 16:12:56] Energy consumed for all CPUs : 0.001417 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:12:56] 0.005431 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:13:11] Energy consumed for RAM : 0.000217 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:13:11] Energy consumed for all GPUs : 0.004308 kWh. Total GPU Power : 116.82949140043146 W
# [codecarbon INFO @ 16:13:11] Energy consumed for all CPUs : 0.001594 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:13:12] 0.006119 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:13:26] Energy consumed for RAM : 0.000241 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:13:26] Energy consumed for all GPUs : 0.004789 kWh. Total GPU Power : 115.49679093627795 W
# [codecarbon INFO @ 16:13:26] Energy consumed for all CPUs : 0.001771 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:13:26] 0.006801 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:13:42] Energy consumed for RAM : 0.000265 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:13:42] Energy consumed for all GPUs : 0.005273 kWh. Total GPU Power : 116.10903698657187 W
# [codecarbon INFO @ 16:13:42] Energy consumed for all CPUs : 0.001948 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:13:42] 0.007486 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:13:57] Energy consumed for RAM : 0.000289 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:13:57] Energy consumed for all GPUs : 0.005759 kWh. Total GPU Power : 116.66245711273392 W
# [codecarbon INFO @ 16:13:57] Energy consumed for all CPUs : 0.002125 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:13:57] 0.008174 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:14:12] Energy consumed for RAM : 0.000314 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:14:12] Energy consumed for all GPUs : 0.006243 kWh. Total GPU Power : 116.01846326056011 W
# [codecarbon INFO @ 16:14:12] Energy consumed for all CPUs : 0.002302 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:14:12] 0.008858 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:14:27] Energy consumed for RAM : 0.000338 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:14:27] Energy consumed for all GPUs : 0.006727 kWh. Total GPU Power : 116.18320967619354 W
# [codecarbon INFO @ 16:14:27] Energy consumed for all CPUs : 0.002479 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:14:27] 0.009543 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:14:42] Energy consumed for RAM : 0.000362 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:14:42] Energy consumed for all GPUs : 0.007212 kWh. Total GPU Power : 116.40034699323355 W
# [codecarbon INFO @ 16:14:42] Energy consumed for all CPUs : 0.002656 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:14:42] 0.010230 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:14:57] Energy consumed for RAM : 0.000386 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:14:57] Energy consumed for all GPUs : 0.007697 kWh. Total GPU Power : 116.47695539879885 W
# [codecarbon INFO @ 16:14:57] Energy consumed for all CPUs : 0.002833 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:14:57] 0.010916 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:15:12] Energy consumed for RAM : 0.000410 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:15:12] Energy consumed for all GPUs : 0.008181 kWh. Total GPU Power : 116.12720077662276 W
# [codecarbon INFO @ 16:15:12] Energy consumed for all CPUs : 0.003010 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:15:12] 0.011601 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:15:27] Energy consumed for RAM : 0.000434 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:15:27] Energy consumed for all GPUs : 0.008660 kWh. Total GPU Power : 115.16563309702755 W
# [codecarbon INFO @ 16:15:27] Energy consumed for all CPUs : 0.003187 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:15:27] 0.012282 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:15:42] Energy consumed for RAM : 0.000458 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:15:42] Energy consumed for all GPUs : 0.009148 kWh. Total GPU Power : 117.04262114169181 W
# [codecarbon INFO @ 16:15:42] Energy consumed for all CPUs : 0.003364 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:15:42] 0.012970 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:15:57] Energy consumed for RAM : 0.000482 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:15:57] Energy consumed for all GPUs : 0.009630 kWh. Total GPU Power : 115.85067468828751 W
# [codecarbon INFO @ 16:15:57] Energy consumed for all CPUs : 0.003542 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:15:57] 0.013654 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:16:12] Energy consumed for RAM : 0.000506 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:16:12] Energy consumed for all GPUs : 0.010110 kWh. Total GPU Power : 115.19914959632608 W
# [codecarbon INFO @ 16:16:12] Energy consumed for all CPUs : 0.003719 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:16:12] 0.014335 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:16:27] Energy consumed for RAM : 0.000531 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:16:27] Energy consumed for all GPUs : 0.010592 kWh. Total GPU Power : 115.76276597554458 W
# [codecarbon INFO @ 16:16:27] Energy consumed for all CPUs : 0.003896 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:16:27] 0.015018 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:16:42] Energy consumed for RAM : 0.000555 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:16:42] Energy consumed for all GPUs : 0.011077 kWh. Total GPU Power : 116.34786758250499 W
# [codecarbon INFO @ 16:16:42] Energy consumed for all CPUs : 0.004073 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:16:42] 0.015704 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:16:57] Energy consumed for RAM : 0.000579 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:16:57] Energy consumed for all GPUs : 0.011561 kWh. Total GPU Power : 116.24963392322074 W
# [codecarbon INFO @ 16:16:57] Energy consumed for all CPUs : 0.004250 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:16:57] 0.016389 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:17:12] Energy consumed for RAM : 0.000603 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:17:12] Energy consumed for all GPUs : 0.012041 kWh. Total GPU Power : 115.22937585143848 W
# [codecarbon INFO @ 16:17:12] Energy consumed for all CPUs : 0.004427 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:17:12] 0.017071 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:17:27] Energy consumed for RAM : 0.000627 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:17:27] Energy consumed for all GPUs : 0.012521 kWh. Total GPU Power : 115.4052626228315 W
# [codecarbon INFO @ 16:17:27] Energy consumed for all CPUs : 0.004604 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:17:27] 0.017752 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:17:42] Energy consumed for RAM : 0.000651 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:17:42] Energy consumed for all GPUs : 0.013008 kWh. Total GPU Power : 116.8314076894603 W
# [codecarbon INFO @ 16:17:42] Energy consumed for all CPUs : 0.004781 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:17:42] 0.018440 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:17:57] Energy consumed for RAM : 0.000675 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:17:57] Energy consumed for all GPUs : 0.013494 kWh. Total GPU Power : 116.66261924139431 W
# [codecarbon INFO @ 16:17:57] Energy consumed for all CPUs : 0.004958 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:17:57] 0.019127 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:18:12] Energy consumed for RAM : 0.000699 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:18:12] Energy consumed for all GPUs : 0.013974 kWh. Total GPU Power : 115.17288284036589 W
# [codecarbon INFO @ 16:18:12] Energy consumed for all CPUs : 0.005135 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:18:12] 0.019808 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:18:27] Energy consumed for RAM : 0.000723 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:18:27] Energy consumed for all GPUs : 0.014457 kWh. Total GPU Power : 116.09770271357064 W
# [codecarbon INFO @ 16:18:27] Energy consumed for all CPUs : 0.005312 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:18:27] 0.020493 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:18:42] Energy consumed for RAM : 0.000747 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:18:42] Energy consumed for all GPUs : 0.014940 kWh. Total GPU Power : 115.89526908150395 W
# [codecarbon INFO @ 16:18:42] Energy consumed for all CPUs : 0.005489 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:18:42] 0.021176 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:18:57] Energy consumed for RAM : 0.000772 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:18:57] Energy consumed for all GPUs : 0.015425 kWh. Total GPU Power : 116.56724989717868 W
# [codecarbon INFO @ 16:18:57] Energy consumed for all CPUs : 0.005666 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:18:57] 0.021863 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:19:12] Energy consumed for RAM : 0.000796 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:19:12] Energy consumed for all GPUs : 0.015907 kWh. Total GPU Power : 115.58801081713206 W
# [codecarbon INFO @ 16:19:12] Energy consumed for all CPUs : 0.005843 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:19:12] 0.022545 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:19:27] Energy consumed for RAM : 0.000820 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:19:27] Energy consumed for all GPUs : 0.016387 kWh. Total GPU Power : 115.44249264449199 W
# [codecarbon INFO @ 16:19:27] Energy consumed for all CPUs : 0.006020 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:19:27] 0.023227 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:19:42] Energy consumed for RAM : 0.000844 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:19:42] Energy consumed for all GPUs : 0.016872 kWh. Total GPU Power : 116.41945659874018 W
# [codecarbon INFO @ 16:19:42] Energy consumed for all CPUs : 0.006197 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:19:42] 0.023913 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:19:57] Energy consumed for RAM : 0.000868 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:19:57] Energy consumed for all GPUs : 0.017357 kWh. Total GPU Power : 116.43221651723913 W
# [codecarbon INFO @ 16:19:57] Energy consumed for all CPUs : 0.006374 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:19:57] 0.024600 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:20:12] Energy consumed for RAM : 0.000892 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:20:12] Energy consumed for all GPUs : 0.017836 kWh. Total GPU Power : 114.97366559334439 W
# [codecarbon INFO @ 16:20:12] Energy consumed for all CPUs : 0.006551 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:20:12] 0.025280 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:20:27] Energy consumed for RAM : 0.000916 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:20:27] Energy consumed for all GPUs : 0.018319 kWh. Total GPU Power : 116.04754536066523 W
# [codecarbon INFO @ 16:20:27] Energy consumed for all CPUs : 0.006729 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:20:27] 0.025964 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:20:42] Energy consumed for RAM : 0.000940 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:20:42] Energy consumed for all GPUs : 0.018776 kWh. Total GPU Power : 109.70253377316558 W
# [codecarbon INFO @ 16:20:42] Energy consumed for all CPUs : 0.006906 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:20:42] 0.026622 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:20:57] Energy consumed for RAM : 0.000964 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:20:57] Energy consumed for all GPUs : 0.019201 kWh. Total GPU Power : 101.90417636618027 W
# [codecarbon INFO @ 16:20:57] Energy consumed for all CPUs : 0.007083 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:20:57] 0.027248 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:21:12] Energy consumed for RAM : 0.000989 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:21:12] Energy consumed for all GPUs : 0.019682 kWh. Total GPU Power : 115.53238373557224 W
# [codecarbon INFO @ 16:21:12] Energy consumed for all CPUs : 0.007260 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:21:12] 0.027930 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:21:27] Energy consumed for RAM : 0.001013 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:21:27] Energy consumed for all GPUs : 0.020169 kWh. Total GPU Power : 116.97426056907769 W
# [codecarbon INFO @ 16:21:27] Energy consumed for all CPUs : 0.007437 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:21:27] 0.028618 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:21:42] Energy consumed for RAM : 0.001037 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:21:42] Energy consumed for all GPUs : 0.020655 kWh. Total GPU Power : 116.58587035979828 W
# [codecarbon INFO @ 16:21:42] Energy consumed for all CPUs : 0.007614 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:21:42] 0.029305 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:21:57] Energy consumed for RAM : 0.001061 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:21:57] Energy consumed for all GPUs : 0.021136 kWh. Total GPU Power : 115.67165075796518 W
# [codecarbon INFO @ 16:21:57] Energy consumed for all CPUs : 0.007791 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:21:57] 0.029988 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:22:12] Energy consumed for RAM : 0.001085 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:22:12] Energy consumed for all GPUs : 0.021620 kWh. Total GPU Power : 116.08751436027337 W
# [codecarbon INFO @ 16:22:12] Energy consumed for all CPUs : 0.007968 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:22:12] 0.030673 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:22:27] Energy consumed for RAM : 0.001109 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:22:27] Energy consumed for all GPUs : 0.022102 kWh. Total GPU Power : 115.56375390448862 W
# [codecarbon INFO @ 16:22:27] Energy consumed for all CPUs : 0.008145 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:22:27] 0.031356 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:22:42] Energy consumed for RAM : 0.001133 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:22:42] Energy consumed for all GPUs : 0.022581 kWh. Total GPU Power : 114.99386681869666 W
# [codecarbon INFO @ 16:22:42] Energy consumed for all CPUs : 0.008322 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:22:42] 0.032036 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:22:57] Energy consumed for RAM : 0.001157 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:22:57] Energy consumed for all GPUs : 0.023063 kWh. Total GPU Power : 115.79307795035524 W
# [codecarbon INFO @ 16:22:57] Energy consumed for all CPUs : 0.008499 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:22:57] 0.032719 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:23:12] Energy consumed for RAM : 0.001181 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:23:12] Energy consumed for all GPUs : 0.023546 kWh. Total GPU Power : 116.00611700025206 W
# [codecarbon INFO @ 16:23:12] Energy consumed for all CPUs : 0.008676 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:23:12] 0.033403 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:23:27] Energy consumed for RAM : 0.001206 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:23:27] Energy consumed for all GPUs : 0.024032 kWh. Total GPU Power : 116.7580558718141 W
# [codecarbon INFO @ 16:23:27] Energy consumed for all CPUs : 0.008853 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:23:27] 0.034091 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:23:42] Energy consumed for RAM : 0.001230 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:23:42] Energy consumed for all GPUs : 0.024515 kWh. Total GPU Power : 115.96847140128752 W
# [codecarbon INFO @ 16:23:42] Energy consumed for all CPUs : 0.009030 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:23:42] 0.034775 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:23:57] Energy consumed for RAM : 0.001254 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:23:57] Energy consumed for all GPUs : 0.024998 kWh. Total GPU Power : 115.76278674891405 W
# [codecarbon INFO @ 16:23:57] Energy consumed for all CPUs : 0.009208 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:23:57] 0.035460 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:24:12] Energy consumed for RAM : 0.001278 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:24:12] Energy consumed for all GPUs : 0.025484 kWh. Total GPU Power : 116.72177121649712 W
# [codecarbon INFO @ 16:24:12] Energy consumed for all CPUs : 0.009385 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:24:12] 0.036146 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:24:27] Energy consumed for RAM : 0.001302 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:24:27] Energy consumed for all GPUs : 0.025966 kWh. Total GPU Power : 115.61223315161038 W
# [codecarbon INFO @ 16:24:27] Energy consumed for all CPUs : 0.009562 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:24:27] 0.036830 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:24:42] Energy consumed for RAM : 0.001326 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:24:42] Energy consumed for all GPUs : 0.026451 kWh. Total GPU Power : 116.41104993063335 W
# [codecarbon INFO @ 16:24:42] Energy consumed for all CPUs : 0.009739 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:24:42] 0.037515 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:24:57] Energy consumed for RAM : 0.001350 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:24:57] Energy consumed for all GPUs : 0.026933 kWh. Total GPU Power : 115.88981678535626 W
# [codecarbon INFO @ 16:24:57] Energy consumed for all CPUs : 0.009916 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:24:57] 0.038199 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:25:12] Energy consumed for RAM : 0.001374 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:25:12] Energy consumed for all GPUs : 0.027419 kWh. Total GPU Power : 116.53187594382149 W
# [codecarbon INFO @ 16:25:12] Energy consumed for all CPUs : 0.010093 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:25:12] 0.038886 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:25:27] Energy consumed for RAM : 0.001398 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:25:27] Energy consumed for all GPUs : 0.027902 kWh. Total GPU Power : 116.00331704708907 W
# [codecarbon INFO @ 16:25:27] Energy consumed for all CPUs : 0.010270 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:25:27] 0.039570 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:25:42] Energy consumed for RAM : 0.001423 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:25:42] Energy consumed for all GPUs : 0.028391 kWh. Total GPU Power : 117.48065615783858 W
# [codecarbon INFO @ 16:25:42] Energy consumed for all CPUs : 0.010447 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:25:42] 0.040260 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:25:57] Energy consumed for RAM : 0.001447 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:25:57] Energy consumed for all GPUs : 0.028876 kWh. Total GPU Power : 116.48034939556607 W
# [codecarbon INFO @ 16:25:57] Energy consumed for all CPUs : 0.010624 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:25:57] 0.040947 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:26:12] Energy consumed for RAM : 0.001471 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:26:12] Energy consumed for all GPUs : 0.029366 kWh. Total GPU Power : 117.57039719164082 W
# [codecarbon INFO @ 16:26:12] Energy consumed for all CPUs : 0.010801 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:26:12] 0.041637 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:26:27] Energy consumed for RAM : 0.001495 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:26:27] Energy consumed for all GPUs : 0.029848 kWh. Total GPU Power : 115.5966587794741 W
# [codecarbon INFO @ 16:26:27] Energy consumed for all CPUs : 0.010978 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:26:27] 0.042321 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:26:42] Energy consumed for RAM : 0.001519 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:26:42] Energy consumed for all GPUs : 0.030335 kWh. Total GPU Power : 117.13451034947326 W
# [codecarbon INFO @ 16:26:42] Energy consumed for all CPUs : 0.011155 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:26:42] 0.043009 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:26:57] Energy consumed for RAM : 0.001543 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:26:57] Energy consumed for all GPUs : 0.030818 kWh. Total GPU Power : 116.04887316834939 W
# [codecarbon INFO @ 16:26:57] Energy consumed for all CPUs : 0.011332 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:26:57] 0.043693 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:27:12] Energy consumed for RAM : 0.001567 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:27:12] Energy consumed for all GPUs : 0.031298 kWh. Total GPU Power : 115.2282588768724 W
# [codecarbon INFO @ 16:27:12] Energy consumed for all CPUs : 0.011509 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:27:12] 0.044374 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:27:27] Energy consumed for RAM : 0.001591 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:27:27] Energy consumed for all GPUs : 0.031782 kWh. Total GPU Power : 116.26366918220737 W
# [codecarbon INFO @ 16:27:27] Energy consumed for all CPUs : 0.011686 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:27:27] 0.045060 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:27:42] Energy consumed for RAM : 0.001615 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:27:42] Energy consumed for all GPUs : 0.032266 kWh. Total GPU Power : 116.21870169958899 W
# [codecarbon INFO @ 16:27:42] Energy consumed for all CPUs : 0.011863 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:27:42] 0.045745 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:27:57] Energy consumed for RAM : 0.001639 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:27:57] Energy consumed for all GPUs : 0.032750 kWh. Total GPU Power : 116.0739462450579 W
# [codecarbon INFO @ 16:27:57] Energy consumed for all CPUs : 0.012040 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:27:57] 0.046430 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:28:12] Energy consumed for RAM : 0.001664 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:28:12] Energy consumed for all GPUs : 0.033236 kWh. Total GPU Power : 116.69082587827091 W
# [codecarbon INFO @ 16:28:12] Energy consumed for all CPUs : 0.012217 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:28:12] 0.047117 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:28:27] Energy consumed for RAM : 0.001688 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:28:27] Energy consumed for all GPUs : 0.033717 kWh. Total GPU Power : 115.66795702558211 W
# [codecarbon INFO @ 16:28:27] Energy consumed for all CPUs : 0.012394 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:28:27] 0.047800 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:28:42] Energy consumed for RAM : 0.001712 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:28:42] Energy consumed for all GPUs : 0.034198 kWh. Total GPU Power : 115.3862060569819 W
# [codecarbon INFO @ 16:28:42] Energy consumed for all CPUs : 0.012572 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:28:42] 0.048481 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:28:57] Energy consumed for RAM : 0.001736 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:28:57] Energy consumed for all GPUs : 0.034681 kWh. Total GPU Power : 116.01098662230747 W
# [codecarbon INFO @ 16:28:57] Energy consumed for all CPUs : 0.012749 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:28:57] 0.049166 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:29:12] Energy consumed for RAM : 0.001760 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:29:12] Energy consumed for all GPUs : 0.035167 kWh. Total GPU Power : 116.63781254278017 W
# [codecarbon INFO @ 16:29:12] Energy consumed for all CPUs : 0.012926 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:29:12] 0.049853 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:29:27] Energy consumed for RAM : 0.001784 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:29:27] Energy consumed for all GPUs : 0.035653 kWh. Total GPU Power : 116.74033904607464 W
# [codecarbon INFO @ 16:29:27] Energy consumed for all CPUs : 0.013103 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:29:27] 0.050540 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:29:42] Energy consumed for RAM : 0.001808 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:29:42] Energy consumed for all GPUs : 0.036142 kWh. Total GPU Power : 117.43482288523761 W
# [codecarbon INFO @ 16:29:42] Energy consumed for all CPUs : 0.013280 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:29:42] 0.051230 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:29:57] Energy consumed for RAM : 0.001832 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:29:57] Energy consumed for all GPUs : 0.036625 kWh. Total GPU Power : 115.95262005557639 W
# [codecarbon INFO @ 16:29:57] Energy consumed for all CPUs : 0.013457 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:29:57] 0.051915 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:30:12] Energy consumed for RAM : 0.001856 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:30:12] Energy consumed for all GPUs : 0.037113 kWh. Total GPU Power : 117.0585237187792 W
# [codecarbon INFO @ 16:30:12] Energy consumed for all CPUs : 0.013634 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:30:12] 0.052603 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:30:27] Energy consumed for RAM : 0.001881 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:30:27] Energy consumed for all GPUs : 0.037582 kWh. Total GPU Power : 112.57333818834361 W
# [codecarbon INFO @ 16:30:27] Energy consumed for all CPUs : 0.013811 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:30:27] 0.053273 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:30:42] Energy consumed for RAM : 0.001905 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:30:42] Energy consumed for all GPUs : 0.038041 kWh. Total GPU Power : 110.31709410504901 W
# [codecarbon INFO @ 16:30:42] Energy consumed for all CPUs : 0.013988 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:30:42] 0.053934 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:30:57] Energy consumed for RAM : 0.001929 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:30:57] Energy consumed for all GPUs : 0.038523 kWh. Total GPU Power : 115.64388527876325 W
# [codecarbon INFO @ 16:30:57] Energy consumed for all CPUs : 0.014165 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:30:57] 0.054617 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:31:12] Energy consumed for RAM : 0.001953 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:31:12] Energy consumed for all GPUs : 0.039007 kWh. Total GPU Power : 116.17059313461736 W
# [codecarbon INFO @ 16:31:12] Energy consumed for all CPUs : 0.014342 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:31:12] 0.055302 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:31:27] Energy consumed for RAM : 0.001977 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:31:27] Energy consumed for all GPUs : 0.039491 kWh. Total GPU Power : 116.28168903624514 W
# [codecarbon INFO @ 16:31:27] Energy consumed for all CPUs : 0.014519 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:31:27] 0.055987 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:31:42] Energy consumed for RAM : 0.002001 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:31:42] Energy consumed for all GPUs : 0.039973 kWh. Total GPU Power : 115.63444502542059 W
# [codecarbon INFO @ 16:31:42] Energy consumed for all CPUs : 0.014696 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:31:42] 0.056670 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:31:57] Energy consumed for RAM : 0.002025 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:31:57] Energy consumed for all GPUs : 0.040455 kWh. Total GPU Power : 115.85864151194839 W
# [codecarbon INFO @ 16:31:57] Energy consumed for all CPUs : 0.014873 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:31:57] 0.057354 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:32:12] Energy consumed for RAM : 0.002049 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:32:12] Energy consumed for all GPUs : 0.040942 kWh. Total GPU Power : 116.83332751829992 W
# [codecarbon INFO @ 16:32:12] Energy consumed for all CPUs : 0.015051 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:32:12] 0.058042 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:32:27] Energy consumed for RAM : 0.002073 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:32:27] Energy consumed for all GPUs : 0.041421 kWh. Total GPU Power : 115.00557548598651 W
# [codecarbon INFO @ 16:32:27] Energy consumed for all CPUs : 0.015228 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:32:27] 0.058722 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:32:42] Energy consumed for RAM : 0.002098 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:32:42] Energy consumed for all GPUs : 0.041905 kWh. Total GPU Power : 116.22174011571816 W
# [codecarbon INFO @ 16:32:42] Energy consumed for all CPUs : 0.015405 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:32:42] 0.059407 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:32:57] Energy consumed for RAM : 0.002122 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:32:57] Energy consumed for all GPUs : 0.042390 kWh. Total GPU Power : 116.63335329004924 W
# [codecarbon INFO @ 16:32:57] Energy consumed for all CPUs : 0.015582 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:32:57] 0.060094 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:33:12] Energy consumed for RAM : 0.002146 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:33:12] Energy consumed for all GPUs : 0.042881 kWh. Total GPU Power : 117.78769208145212 W
# [codecarbon INFO @ 16:33:12] Energy consumed for all CPUs : 0.015759 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:33:12] 0.060785 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:33:27] Energy consumed for RAM : 0.002170 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:33:27] Energy consumed for all GPUs : 0.043366 kWh. Total GPU Power : 116.31393888494529 W
# [codecarbon INFO @ 16:33:27] Energy consumed for all CPUs : 0.015936 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:33:27] 0.061471 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:33:42] Energy consumed for RAM : 0.002194 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:33:42] Energy consumed for all GPUs : 0.043848 kWh. Total GPU Power : 115.97763692034692 W
# [codecarbon INFO @ 16:33:42] Energy consumed for all CPUs : 0.016113 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:33:42] 0.062155 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:33:57] Energy consumed for RAM : 0.002218 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:33:57] Energy consumed for all GPUs : 0.044336 kWh. Total GPU Power : 116.93313606222291 W
# [codecarbon INFO @ 16:33:57] Energy consumed for all CPUs : 0.016290 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:33:57] 0.062844 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:34:12] Energy consumed for RAM : 0.002242 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:34:12] Energy consumed for all GPUs : 0.044816 kWh. Total GPU Power : 115.22853259268564 W
# [codecarbon INFO @ 16:34:12] Energy consumed for all CPUs : 0.016467 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:34:12] 0.063525 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:34:27] Energy consumed for RAM : 0.002266 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:34:27] Energy consumed for all GPUs : 0.045299 kWh. Total GPU Power : 116.14376307300947 W
# [codecarbon INFO @ 16:34:27] Energy consumed for all CPUs : 0.016644 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:34:27] 0.064210 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:34:42] Energy consumed for RAM : 0.002290 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:34:42] Energy consumed for all GPUs : 0.045784 kWh. Total GPU Power : 116.52076809727333 W
# [codecarbon INFO @ 16:34:42] Energy consumed for all CPUs : 0.016821 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:34:42] 0.064896 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:34:57] Energy consumed for RAM : 0.002315 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:34:57] Energy consumed for all GPUs : 0.046274 kWh. Total GPU Power : 117.66356596330199 W
# [codecarbon INFO @ 16:34:57] Energy consumed for all CPUs : 0.016998 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:34:57] 0.065587 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:35:12] Energy consumed for RAM : 0.002339 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:35:12] Energy consumed for all GPUs : 0.046759 kWh. Total GPU Power : 116.25960178009373 W
# [codecarbon INFO @ 16:35:12] Energy consumed for all CPUs : 0.017176 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:35:12] 0.066273 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:35:27] Energy consumed for RAM : 0.002363 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:35:27] Energy consumed for all GPUs : 0.047241 kWh. Total GPU Power : 115.85933785156057 W
# [codecarbon INFO @ 16:35:27] Energy consumed for all CPUs : 0.017352 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:35:27] 0.066956 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:35:42] Energy consumed for RAM : 0.002387 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:35:42] Energy consumed for all GPUs : 0.047719 kWh. Total GPU Power : 114.6789654707578 W
# [codecarbon INFO @ 16:35:42] Energy consumed for all CPUs : 0.017530 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:35:42] 0.067635 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:35:57] Energy consumed for RAM : 0.002411 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:35:57] Energy consumed for all GPUs : 0.048206 kWh. Total GPU Power : 116.80868153397462 W
# [codecarbon INFO @ 16:35:57] Energy consumed for all CPUs : 0.017707 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:35:57] 0.068323 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:36:12] Energy consumed for RAM : 0.002435 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:36:12] Energy consumed for all GPUs : 0.048686 kWh. Total GPU Power : 115.31547859178819 W
# [codecarbon INFO @ 16:36:12] Energy consumed for all CPUs : 0.017884 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:36:12] 0.069004 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:36:27] Energy consumed for RAM : 0.002459 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:36:27] Energy consumed for all GPUs : 0.049168 kWh. Total GPU Power : 115.74444750494426 W
# [codecarbon INFO @ 16:36:27] Energy consumed for all CPUs : 0.018061 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:36:27] 0.069688 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:36:42] Energy consumed for RAM : 0.002483 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:36:42] Energy consumed for all GPUs : 0.049645 kWh. Total GPU Power : 114.62446576552202 W
# [codecarbon INFO @ 16:36:42] Energy consumed for all CPUs : 0.018238 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:36:42] 0.070366 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:36:57] Energy consumed for RAM : 0.002507 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:36:57] Energy consumed for all GPUs : 0.050137 kWh. Total GPU Power : 117.91993418648043 W
# [codecarbon INFO @ 16:36:57] Energy consumed for all CPUs : 0.018415 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:36:57] 0.071059 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:37:12] Energy consumed for RAM : 0.002531 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:37:12] Energy consumed for all GPUs : 0.050618 kWh. Total GPU Power : 115.63007918196999 W
# [codecarbon INFO @ 16:37:12] Energy consumed for all CPUs : 0.018592 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:37:12] 0.071741 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:37:27] Energy consumed for RAM : 0.002556 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:37:27] Energy consumed for all GPUs : 0.051109 kWh. Total GPU Power : 117.79555150417549 W
# [codecarbon INFO @ 16:37:27] Energy consumed for all CPUs : 0.018769 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:37:27] 0.072434 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:37:42] Energy consumed for RAM : 0.002580 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:37:42] Energy consumed for all GPUs : 0.051595 kWh. Total GPU Power : 116.69135934386125 W
# [codecarbon INFO @ 16:37:42] Energy consumed for all CPUs : 0.018946 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:37:42] 0.073121 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:37:57] Energy consumed for RAM : 0.002604 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:37:57] Energy consumed for all GPUs : 0.052082 kWh. Total GPU Power : 116.88779830956008 W
# [codecarbon INFO @ 16:37:57] Energy consumed for all CPUs : 0.019123 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:37:57] 0.073809 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:38:12] Energy consumed for RAM : 0.002628 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:38:12] Energy consumed for all GPUs : 0.052566 kWh. Total GPU Power : 116.23805223833958 W
# [codecarbon INFO @ 16:38:12] Energy consumed for all CPUs : 0.019300 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:38:12] 0.074494 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:38:27] Energy consumed for RAM : 0.002652 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:38:27] Energy consumed for all GPUs : 0.053053 kWh. Total GPU Power : 116.77030853810773 W
# [codecarbon INFO @ 16:38:27] Energy consumed for all CPUs : 0.019478 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:38:27] 0.075182 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:38:42] Energy consumed for RAM : 0.002676 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 16:38:42] Energy consumed for all GPUs : 0.053542 kWh. Total GPU Power : 117.42713467592601 W
# [codecarbon INFO @ 16:38:42] Energy consumed for all CPUs : 0.019655 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:38:42] 0.075872 kWh of electricity used since the beginning.
# ...
# COMET INFO:     args/adafactor                          : False
# COMET INFO:     args/adam_beta1                         : 0.9
# COMET INFO:     args/adam_beta2                         : 0.999
# COMET INFO:     args/adam_epsilon                       : 1e-08
# COMET INFO:     args/auto_find_batch_size               : False
# COMET INFO:     args/bf16                               : False
# COMET INFO:     args/bf16_full_eval                     : False
# COMET INFO:     args/data_seed                          : None
# COMET INFO:     args/dataloader_drop_last               : False
# COMET INFO:     args/dataloader_num_workers             : 0
# COMET INFO:     args/dataloader_persistent_workers      : False
# COMET INFO:     args/dataloader_pin_memory              : True
# COMET INFO:     args/dataloader_prefetch_factor         : None
# COMET INFO:     args/ddp_backend                        : None
# COMET INFO:     args/ddp_broadcast_buffers              : None
# COMET INFO:     args/ddp_bucket_cap_mb                  : None
# COMET INFO:     args/ddp_find_unused_parameters         : None
# COMET INFO:     args/ddp_timeout                        : 1800
# COMET INFO:     args/ddp_timeout_delta                  : 0:30:00
# COMET INFO:     args/debug                              : []
# COMET INFO:     args/deepspeed                          : None
# COMET INFO:     args/deepspeed_plugin                   : None
# COMET INFO:     args/default_optim                      : adamw_torch
# COMET INFO:     args/device                             : cuda:0
# COMET INFO:     args/disable_tqdm                       : False
# COMET INFO:     args/dispatch_batches                   : None
# COMET INFO:     args/distributed_state                  : Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# COMET INFO:     args/do_eval                            : True
# COMET INFO:     args/do_predict                         : False
# COMET INFO:     args/do_train                           : False
# COMET INFO:     args/eval_accumulation_steps            : None
# COMET INFO:     args/eval_batch_size                    : 8
# COMET INFO:     args/eval_delay                         : 0
# COMET INFO:     args/eval_steps                         : None
# COMET INFO:     args/evaluation_strategy                : IntervalStrategy.EPOCH
# COMET INFO:     args/fp16                               : True
# COMET INFO:     args/fp16_backend                       : auto
# COMET INFO:     args/fp16_full_eval                     : False
# COMET INFO:     args/fp16_opt_level                     : O1
# COMET INFO:     args/framework                          : pt
# COMET INFO:     args/fsdp                               : []
# COMET INFO:     args/fsdp_config                        : {'min_num_params': 0, 'xla': False, 'xla_fsdp_v2': False, 'xla_fsdp_grad_ckpt': False}
# COMET INFO:     args/fsdp_min_num_params                : 0
# COMET INFO:     args/fsdp_transformer_layer_cls_to_wrap : None
# COMET INFO:     args/full_determinism                   : False
# COMET INFO:     args/gradient_accumulation_steps        : 1
# COMET INFO:     args/gradient_checkpointing             : False
# COMET INFO:     args/gradient_checkpointing_kwargs      : None
# COMET INFO:     args/greater_is_better                  : None
# COMET INFO:     args/group_by_length                    : False
# COMET INFO:     args/half_precision_backend             : auto
# COMET INFO:     args/hub_always_push                    : False
# COMET INFO:     args/hub_model_id                       : None
# COMET INFO:     args/hub_private_repo                   : False
# COMET INFO:     args/hub_strategy                       : HubStrategy.EVERY_SAVE
# COMET INFO:     args/hub_token                          : None
# COMET INFO:     args/ignore_data_skip                   : False
# COMET INFO:     args/include_inputs_for_metrics         : False
# COMET INFO:     args/include_num_input_tokens_seen      : False
# COMET INFO:     args/include_tokens_per_second          : False
# COMET INFO:     args/jit_mode_eval                      : False
# COMET INFO:     args/label_names                        : None
# COMET INFO:     args/label_smoothing_factor             : 0.0
# COMET INFO:     args/learning_rate                      : 2e-05
# COMET INFO:     args/length_column_name                 : length
# COMET INFO:     args/load_best_model_at_end             : False
# COMET INFO:     args/local_process_index                : 0
# COMET INFO:     args/local_rank                         : 0
# COMET INFO:     args/log_level                          : passive
# COMET INFO:     args/log_level_replica                  : warning
# COMET INFO:     args/log_on_each_node                   : True
# COMET INFO:     args/logging_dir                        : bert-finetuned-squad/runs/Apr03_16-10-52_c84b5018c7e3
# COMET INFO:     args/logging_first_step                 : False
# COMET INFO:     args/logging_nan_inf_filter             : True
# COMET INFO:     args/logging_steps                      : 100
# COMET INFO:     args/logging_strategy                   : IntervalStrategy.EPOCH
# COMET INFO:     args/lr_scheduler_kwargs                : {}
# COMET INFO:     args/lr_scheduler_type                  : SchedulerType.LINEAR
# COMET INFO:     args/max_grad_norm                      : 1.0
# COMET INFO:     args/max_steps                          : -1
# COMET INFO:     args/metric_for_best_model              : None
# COMET INFO:     args/mp_parameters                      :
# COMET INFO:     args/n_gpu                              : 1
# COMET INFO:     args/neftune_noise_alpha                : None
# COMET INFO:     args/no_cuda                            : False
# COMET INFO:     args/num_train_epochs                   : 3
# COMET INFO:     args/optim                              : OptimizerNames.ADAMW_TORCH
# COMET INFO:     args/optim_args                         : None
# COMET INFO:     args/optim_target_modules               : None
# COMET INFO:     args/output_dir                         : bert-finetuned-squad
# COMET INFO:     args/overwrite_output_dir               : False
# COMET INFO:     args/parallel_mode                      : ParallelMode.NOT_PARALLEL
# COMET INFO:     args/past_index                         : -1
# COMET INFO:     args/per_device_eval_batch_size         : 8
# COMET INFO:     args/per_device_train_batch_size        : 8
# COMET INFO:     args/per_gpu_eval_batch_size            : None
# COMET INFO:     args/per_gpu_train_batch_size           : None
# COMET INFO:     args/place_model_on_device              : True
# COMET INFO:     args/prediction_loss_only               : False
# COMET INFO:     args/process_index                      : 0
# COMET INFO:     args/push_to_hub                        : True
# COMET INFO:     args/push_to_hub_model_id               : None
# COMET INFO:     args/push_to_hub_organization           : None
# COMET INFO:     args/push_to_hub_token                  : None
# COMET INFO:     args/ray_scope                          : last
# COMET INFO:     args/remove_unused_columns              : True
# COMET INFO:     args/report_to                          : ['comet_ml']
# COMET INFO:     args/resume_from_checkpoint             : None
# COMET INFO:     args/run_name                           : bert-finetuned-squad
# COMET INFO:     args/save_on_each_node                  : False
# COMET INFO:     args/save_only_model                    : False
# COMET INFO:     args/save_safetensors                   : True
# COMET INFO:     args/save_steps                         : 500
# COMET INFO:     args/save_strategy                      : IntervalStrategy.EPOCH
# COMET INFO:     args/save_total_limit                   : 1
# COMET INFO:     args/seed                               : 42
# COMET INFO:     args/should_log                         : True
# COMET INFO:     args/should_save                        : True
# COMET INFO:     args/skip_memory_metrics                : True
# COMET INFO:     args/split_batches                      : None
# COMET INFO:     args/tf32                               : None
# COMET INFO:     args/torch_compile                      : False
# COMET INFO:     args/torch_compile_backend              : None
# COMET INFO:     args/torch_compile_mode                 : None
# COMET INFO:     args/torchdynamo                        : None
# COMET INFO:     args/tpu_metrics_debug                  : False
# COMET INFO:     args/tpu_num_cores                      : None
# COMET INFO:     args/train_batch_size                   : 8
# COMET INFO:     args/use_cpu                            : False
# COMET INFO:     args/use_ipex                           : False
# COMET INFO:     args/use_legacy_prediction_loop         : False
# COMET INFO:     args/use_mps_device                     : False
# COMET INFO:     args/warmup_ratio                       : 0.0
# COMET INFO:     args/warmup_steps                       : 0
# COMET INFO:     args/weight_decay                       : 0.01
# COMET INFO:     args/world_size                         : 1
# COMET INFO:     config/_attn_implementation             : eager
# COMET INFO:     config/_attn_implementation_internal    : None
# COMET INFO:     config/_auto_class                      : None
# COMET INFO:     config/_commit_hash                     : 0dacbb01d604f8adeeb5b87c9339e485ac40d5c0
# COMET INFO:     config/_name_or_path                    : distilbert-base-cased
# COMET INFO:     config/activation                       : gelu
# COMET INFO:     config/add_cross_attention              : False
# COMET INFO:     config/architectures                    : ['DistilBertForMaskedLM']
# COMET INFO:     config/attention_dropout                : 0.1
# COMET INFO:     config/attribute_map                    : {'hidden_size': 'dim', 'num_attention_heads': 'n_heads', 'num_hidden_layers': 'n_layers'}
# COMET INFO:     config/bad_words_ids                    : None
# COMET INFO:     config/begin_suppress_tokens            : None
# COMET INFO:     config/bos_token_id                     : None
# COMET INFO:     config/chunk_size_feed_forward          : 0
# COMET INFO:     config/cross_attention_hidden_size      : None
# COMET INFO:     config/decoder_start_token_id           : None
# COMET INFO:     config/dim                              : 768
# COMET INFO:     config/diversity_penalty                : 0.0
# COMET INFO:     config/do_sample                        : False
# COMET INFO:     config/dropout                          : 0.1
# COMET INFO:     config/early_stopping                   : False
# COMET INFO:     config/encoder_no_repeat_ngram_size     : 0
# COMET INFO:     config/eos_token_id                     : None
# COMET INFO:     config/exponential_decay_length_penalty : None
# COMET INFO:     config/finetuning_task                  : None
# COMET INFO:     config/forced_bos_token_id              : None
# COMET INFO:     config/forced_eos_token_id              : None
# COMET INFO:     config/hidden_dim                       : 3072
# COMET INFO:     config/id2label                         : {0: 'LABEL_0', 1: 'LABEL_1'}
# COMET INFO:     config/initializer_range                : 0.02
# COMET INFO:     config/is_composition                   : False
# COMET INFO:     config/is_decoder                       : False
# COMET INFO:     config/is_encoder_decoder               : False
# COMET INFO:     config/label2id                         : {'LABEL_0': 0, 'LABEL_1': 1}
# COMET INFO:     config/length_penalty                   : 1.0
# COMET INFO:     config/max_length                       : 20
# COMET INFO:     config/max_position_embeddings          : 512
# COMET INFO:     config/min_length                       : 0
# COMET INFO:     config/model_type                       : distilbert
# COMET INFO:     config/n_heads                          : 12
# COMET INFO:     config/n_layers                         : 6
# COMET INFO:     config/name_or_path                     : distilbert-base-cased
# COMET INFO:     config/no_repeat_ngram_size             : 0
# COMET INFO:     config/num_beam_groups                  : 1
# COMET INFO:     config/num_beams                        : 1
# COMET INFO:     config/num_labels                       : 2
# COMET INFO:     config/num_return_sequences             : 1
# COMET INFO:     config/output_attentions                : False
# COMET INFO:     config/output_hidden_states             : False
# COMET INFO:     config/output_past                      : True
# COMET INFO:     config/output_scores                    : False
# COMET INFO:     config/pad_token_id                     : 0
# COMET INFO:     config/prefix                           : None
# COMET INFO:     config/problem_type                     : None
# COMET INFO:     config/pruned_heads                     : {}
# COMET INFO:     config/qa_dropout                       : 0.1
# COMET INFO:     config/remove_invalid_values            : False
# COMET INFO:     config/repetition_penalty               : 1.0
# COMET INFO:     config/return_dict                      : True
# COMET INFO:     config/return_dict_in_generate          : False
# COMET INFO:     config/sep_token_id                     : None
# COMET INFO:     config/seq_classif_dropout              : 0.2
# COMET INFO:     config/sinusoidal_pos_embds             : False
# COMET INFO:     config/suppress_tokens                  : None
# COMET INFO:     config/task_specific_params             : None
# COMET INFO:     config/temperature                      : 1.0
# COMET INFO:     config/tf_legacy_loss                   : False
# COMET INFO:     config/tie_encoder_decoder              : False
# COMET INFO:     config/tie_weights_                     : True
# COMET INFO:     config/tie_word_embeddings              : True
# COMET INFO:     config/tokenizer_class                  : None
# COMET INFO:     config/top_k                            : 50
# COMET INFO:     config/top_p                            : 1.0
# COMET INFO:     config/torch_dtype                      : None
# COMET INFO:     config/torchscript                      : False
# COMET INFO:     config/transformers_version             : None
# COMET INFO:     config/typical_p                        : 1.0
# COMET INFO:     config/use_bfloat16                     : False
# COMET INFO:     config/use_return_dict                  : True
# COMET INFO:     config/vocab_size                       : 28996
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 20 (996.58 MB)
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET ERROR: Error sending a notification, make sure you have opted-in for notifications
# COMET INFO: Please wait for assets to finish uploading (timeout is 10800 seconds)
# COMET INFO: Still uploading 3 file(s), remaining 979.86 MB/994.86 MB
# COMET INFO: Still uploading 3 asset(s), remaining 884.86 MB/994.86 MB, Throughput 6.32 MB/s, ETA ~140s
# COMET INFO: Still uploading 3 asset(s), remaining 724.86 MB/994.86 MB, Throughput 10.65 MB/s, ETA ~69s
# COMET INFO: Still uploading 3 asset(s), remaining 564.86 MB/994.86 MB, Throughput 10.65 MB/s, ETA ~54s
# COMET INFO: Still uploading 3 asset(s), remaining 414.86 MB/994.86 MB, Throughput 9.99 MB/s, ETA ~42s
# COMET INFO: Still uploading 1 asset(s), remaining 272.46 MB/497.46 MB, Throughput 9.48 MB/s, ETA ~29s
# COMET INFO: Still uploading 1 asset(s), remaining 192.46 MB/497.46 MB, Throughput 5.33 MB/s, ETA ~37s
# COMET INFO: Still uploading 1 asset(s), remaining 112.46 MB/497.46 MB, Throughput 5.33 MB/s, ETA ~22s
# COMET INFO: Still uploading 1 asset(s), remaining 32.46 MB/497.46 MB, Throughput 5.33 MB/s, ETA ~7s
# TrainOutput(global_step=33276, training_loss=1.0520932820858127, metrics={'train_runtime': 1772.9342, 'train_samples_per_second': 150.139, 'train_steps_per_second': 18.769, 'total_flos': 2.608361755366349e+16, 'train_loss': 1.0520932820858127, 'epoch': 3.0})

# %%
predictions, _, _ = trainer.predict(validation_dataset)
start_logits, end_logits = predictions
compute_metrics(start_logits, end_logits, validation_dataset, raw_datasets["validation"])
# Out:
#   0%|          | 0/10570 [00:00<?, ?it/s]
# {'exact_match': 77.25638599810786, 'f1': 85.08451326485039}

# %%
trainer.push_to_hub(commit_message="Training complete")
# Out:
# 'https://huggingface.co/noushsuon/bert-finetuned-squad/tree/main/'

# %%
from torch.utils.data import DataLoader
from transformers import default_data_collator

train_dataset.set_format("torch")
validation_set = validation_dataset.remove_columns(["example_id", "offset_mapping"])
validation_set.set_format("torch")

train_dataloader = DataLoader(
    train_dataset,
    shuffle=True,
    collate_fn=default_data_collator,
    batch_size=8,
)
eval_dataloader = DataLoader(
    validation_set, collate_fn=default_data_collator, batch_size=8
)

# %%
from torch.optim import AdamW

optimizer = AdamW(model.parameters(), lr=2e-5)

# %%
from accelerate import Accelerator

accelerator = Accelerator()
model, optimizer, train_dataloader, eval_dataloader = accelerator.prepare(
    model, optimizer, train_dataloader, eval_dataloader
)

# %%
from transformers import get_scheduler

num_train_epochs = 3
num_update_steps_per_epoch = len(train_dataloader)
num_training_steps = num_train_epochs * num_update_steps_per_epoch

lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=num_training_steps,
)

# %%
from huggingface_hub import Repository, get_full_repo_name
model_name = "bert-finetuned-squad"
repo_name = get_full_repo_name(model_name)
repo_name
# Out:
# 'noushsuon/bert-finetuned-squad'

# %%
from huggingface_hub import Repository
output_dir = "bert-finetuned-squad-accelerate" + model_checkpoint

repo = Repository(output_dir, clone_from=repo_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:127: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# Cloning https://huggingface.co/noushsuon/bert-finetuned-squad into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/noushsuon/bert-finetuned-squad into local empty directory.
# Download file model.safetensors:   0%|          | 1.45k/249M [00:00<?, ?B/s]
# Download file runs/Feb19_21-04-07_a1e3143d30be/events.out.tfevents.1708376647.a1e3143d30be.826.0: 100%|#######…
# Download file runs/Mar01_17-52-21_9c4a085fe430/events.out.tfevents.1709315550.9c4a085fe430.438.1: 100%|#######…
# Download file runs/Jan31_16-09-00_dcaff34ff298/events.out.tfevents.1706874684.dcaff34ff298.1318.0: 100%|######…
# Download file runs/Mar01_10-58-51_9c4a085fe430/events.out.tfevents.1709290732.9c4a085fe430.438.0: 100%|#######…
# Download file training_args.bin: 100%|##########| 4.80k/4.80k [00:00<?, ?B/s]
# Clean file runs/Feb19_21-04-07_a1e3143d30be/events.out.tfevents.1708376647.a1e3143d30be.826.0:  13%|#3        …
# Clean file runs/Mar01_17-52-21_9c4a085fe430/events.out.tfevents.1709315550.9c4a085fe430.438.1:  24%|##4       …
# Clean file runs/Jan31_16-09-00_dcaff34ff298/events.out.tfevents.1706874684.dcaff34ff298.1318.0:   7%|6        …
# Clean file runs/Mar01_10-58-51_9c4a085fe430/events.out.tfevents.1709290732.9c4a085fe430.438.0:  22%|##2       …
# Clean file training_args.bin:  21%|##        | 1.00k/4.80k [00:00<?, ?B/s]
# Clean file model.safetensors:   0%|          | 1.00k/249M [00:00<?, ?B/s]

# %%
from tqdm.auto import tqdm
import torch

progress_bar = tqdm(range(num_training_steps))

for epoch in range(num_train_epochs):
    # Training
    model.train()
    for step, batch in enumerate(train_dataloader):
        outputs = model(**batch)
        loss = outputs.loss
        accelerator.backward(loss)

        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)

    # Evaluation
    model.eval()
    start_logits = []
    end_logits = []
    accelerator.print("Evaluation!")
    for batch in tqdm(eval_dataloader):
        with torch.no_grad():
            outputs = model(**batch)

        start_logits.append(accelerator.gather(outputs.start_logits).cpu().numpy())
        end_logits.append(accelerator.gather(outputs.end_logits).cpu().numpy())

    start_logits = np.concatenate(start_logits)
    end_logits = np.concatenate(end_logits)
    start_logits = start_logits[: len(validation_dataset)]
    end_logits = end_logits[: len(validation_dataset)]

    metrics = compute_metrics(
        start_logits, end_logits, validation_dataset, raw_datasets["validation"]
    )

    for key, value in metrics.items():
        experiment.log_metric(key, value)

    print(f"epoch {epoch}:", metrics)

    # Save and upload
    accelerator.wait_for_everyone()
    unwrapped_model = accelerator.unwrap_model(model)
    unwrapped_model.save_pretrained(output_dir, save_function=accelerator.save)
    if accelerator.is_main_process:
        tokenizer.save_pretrained(output_dir)
        repo.push_to_hub(
            commit_message=f"Training in progress epoch {epoch}", blocking=False
        )
# Out:
#   0%|          | 0/33276 [00:00<?, ?it/s]
# Evaluation!
#   0%|          | 0/1353 [00:00<?, ?it/s]
#   0%|          | 0/10570 [00:00<?, ?it/s]
# epoch 0: {'exact_match': 74.92904446546831, 'f1': 83.73985008504484}
# Evaluation!
#   0%|          | 0/1353 [00:00<?, ?it/s]
#   0%|          | 0/10570 [00:00<?, ?it/s]
# epoch 1: {'exact_match': 76.70766319772942, 'f1': 85.04632480053613}
# Evaluation!
#   0%|          | 0/1353 [00:00<?, ?it/s]
#   0%|          | 0/10570 [00:00<?, ?it/s]
# epoch 2: {'exact_match': 76.90633869441817, 'f1': 85.3819726622874}

# %%
accelerator.wait_for_everyone()
unwrapped_model = accelerator.unwrap_model(model)
unwrapped_model.save_pretrained(output_dir, save_function=accelerator.save)

# %%
from transformers import pipeline

model_checkpoint = "noushsuon/bert-finetuned-squad"
question_answerer = pipeline("question-answering", model=model_checkpoint)

context = """
Bill is Andrew's father
"""
question = "Who is Bill?"
answer = question_answerer(question=question, context=context)

experiment.log_text("Question", question)
experiment.log_text("Context", context)
experiment.log_text("Answer", answer)
# Out:
# config.json:   0%|          | 0.00/582 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]

# %%
context = """
Bill is Andrew's father
"""
question = "Who is Bill's father?"
answer = question_answerer(question=question, context=context)
print(context, question)
print(answer)
# Out:
# Bill is Andrew's father
#  Who is Bill's father?
# {'score': 0.9533281326293945, 'start': 9, 'end': 15, 'answer': 'Andrew'}

# %%
context = """
Bill is Andrew's father
"""
question = "Who is Andrew's son?"
answer = question_answerer(question=question, context=context)
print(context, question)
print(answer)
# Out:
# Bill is Andrew's father
#  Who is Andrew's son?
# {'score': 0.9823604226112366, 'start': 1, 'end': 5, 'answer': 'Bill'}
