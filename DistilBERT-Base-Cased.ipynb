# %% [markdown]
# <a href="https://colab.research.google.com/github/noushsuon/honours-project/blob/edit-carbon-configuration/DistilBERT-Base-Cased.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install comet-ml
# !pip install cumulator
# !pip install geopy
# !pip install GPUtil
# !pip install py-cpuinfo
# !pip install datasets
# !pip install evaluate
# !pip install accelerate -U
# !pip install codecarbon
# !pip install transformers
# !pip install tokenizers

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import comet_ml
from comet_ml import Experiment
from transformers import AutoModelForSequenceClassification, Trainer, TrainingArguments

import csv
hardwareFile = "/usr/local/lib/python3.10/dist-packages/codecarbon/data/hardware/cpu_power.csv"
cpu_data = ['13th Gen Intel(R) Core(TM) i9-13950HX', 55]
row_present = False
with open(hardwareFile, 'r', newline='') as file:
    reader = csv.reader(file)
    for row in reader:
        if row == cpu_data:
            row_present = True
            break

if not row_present:
    with open(hardwareFile, 'a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(cpu_data)

comet_ml.init(api_key='uyaIbaxDfy7jK9j7u4KNxeKNg',project_name='comet-bert-experiment')
experiment = comet_ml.Experiment(api_key="uyaIbaxDfy7jK9j7u4KNxeKNg",project_name="comet-bert-experiment",)
# Out:
# COMET INFO: Valid Comet API Key saved in /root/.comet.config (set COMET_CONFIG to change where it is saved).
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# [codecarbon INFO @ 09:06:59] [setup] RAM Tracking...
# [codecarbon INFO @ 09:06:59] [setup] GPU Tracking...
# [codecarbon INFO @ 09:07:01] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 09:07:01] [setup] CPU Tracking...
# [codecarbon WARNING @ 09:07:01] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 09:07:02] CPU Model on constant consumption mode: 13th Gen Intel(R) Core(TM) i9-13950HX
# [codecarbon INFO @ 09:07:02] >>> Tracker's metadata:
# [codecarbon INFO @ 09:07:02]   Platform system: Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 09:07:02]   Python version: 3.10.12
# [codecarbon INFO @ 09:07:02]   CodeCarbon version: 2.3.5
# [codecarbon INFO @ 09:07:02]   Available RAM : 15.439 GB
# [codecarbon INFO @ 09:07:02]   CPU count: 32
# [codecarbon INFO @ 09:07:02]   CPU model: 13th Gen Intel(R) Core(TM) i9-13950HX
# [codecarbon INFO @ 09:07:02]   GPU count: 1
# [codecarbon INFO @ 09:07:02]   GPU model: 1 x NVIDIA GeForce RTX 4090 Laptop GPU
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/noushsuon/comet-bert-experiment/1d7f505c6812447ab1f62ba2cdd8fdad

# %%
hardwareFile = "/usr/local/lib/python3.10/dist-packages/cumulator/hardware_data/cpu.csv"
cpu_data = ['Core i9-13950HX', 'Raptor Lake-HX', '1 / 23','2.2 to 5.5 GHz','BGA 1964 ','10 nm', '36 MB', '55 W', 55]

row_present = False
with open(hardwareFile, 'r', newline='') as file:
    reader = csv.reader(file)
    for row in reader:
        if row == cpu_data:
            row_present = True
            break

if not row_present:
    with open(hardwareFile, 'a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(cpu_data)

# %%
baseFile = "/usr/local/lib/python3.10/dist-packages/cumulator/base.py"
with open(baseFile, 'r') as file:
        content = file.read()
with open(baseFile, 'w') as file:
        file.write(content.replace("src.cumulator", "cumulator"))
from cumulator import base
cumulator = base.Cumulator()
cumulator.on()
# Out:
# CPU recognized: TDP set to 55

# %%
from datasets import load_dataset
from transformers import AutoTokenizer

model_checkpoint = "distilbert-base-cased"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

raw_datasets = load_dataset("squad")
raw_datasets
# Out:
# [codecarbon INFO @ 09:07:17] Energy consumed for RAM : 0.000024 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:07:17] Energy consumed for all GPUs : 0.000050 kWh. Total GPU Power : 11.998682215908909 W
# [codecarbon INFO @ 09:07:17] Energy consumed for all CPUs : 0.000117 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:07:17] 0.000192 kWh of electricity used since the beginning.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 87599
#     })
#     validation: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 10570
#     })
# })

# %%
context = raw_datasets["train"][0]["context"]
question = raw_datasets["train"][0]["question"]

inputs = tokenizer(question, context)
tokenizer.decode(inputs["input_ids"])
# Out:
# '[CLS] To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France? [SEP] Architecturally, the school has a Catholic character. Atop the Main Building\'s gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend " Venite Ad Me Omnes ". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive ( and in a direct line that connects through 3 statues and the Gold Dome ), is a simple, modern stone statue of Mary. [SEP]'

# %%
max_length = 384
stride = 128


def preprocess_training_examples(examples):
    questions = [q.strip() for q in examples["question"]]
    inputs = tokenizer(
        questions,
        examples["context"],
        max_length=max_length,
        truncation="only_second", #only truncates the context
        stride=stride,
        return_overflowing_tokens=True, #model will store strings ignored when truncating
        return_offsets_mapping=True, #stores the location of tokens in original text
        padding="max_length",
    )

    offset_mapping = inputs.pop("offset_mapping")
    sample_map = inputs.pop("overflow_to_sample_mapping")
    answers = examples["answers"]
    start_positions = []
    end_positions = []

    for i, offset in enumerate(offset_mapping):
        sample_idx = sample_map[i]
        answer = answers[sample_idx]
        start_char = answer["answer_start"][0]
        end_char = answer["answer_start"][0] + len(answer["text"][0])
        sequence_ids = inputs.sequence_ids(i)

        # Find the start and end of the context
        idx = 0
        while sequence_ids[idx] != 1:
            idx += 1
        context_start = idx
        while sequence_ids[idx] == 1:
            idx += 1
        context_end = idx - 1

        # If the answer is not fully inside the context, label is (0, 0)
        if offset[context_start][0] > start_char or offset[context_end][1] < end_char:
            start_positions.append(0)
            end_positions.append(0)
        else:
            # Otherwise it's the start and end token positions
            idx = context_start
            while idx <= context_end and offset[idx][0] <= start_char:
                idx += 1
            start_positions.append(idx - 1)

            idx = context_end
            while idx >= context_start and offset[idx][1] >= end_char:
                idx -= 1
            end_positions.append(idx + 1)

    inputs["start_positions"] = start_positions
    inputs["end_positions"] = end_positions
    return inputs

# %%
#use previously defined function to preprocess training data
train_dataset = raw_datasets["train"].map(
    preprocess_training_examples,
    batched=True,
    remove_columns=raw_datasets["train"].column_names,
)
len(raw_datasets["train"]), len(train_dataset) #check the sentences have been tokenised
# Out:
# Map:   0%|          | 0/87599 [00:00<?, ? examples/s]
# [codecarbon INFO @ 09:07:32] Energy consumed for RAM : 0.000048 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:07:32] Energy consumed for all GPUs : 0.000115 kWh. Total GPU Power : 15.891741593778919 W
# [codecarbon INFO @ 09:07:32] Energy consumed for all CPUs : 0.000232 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:07:32] 0.000395 kWh of electricity used since the beginning.
# (87599, 88729)

# %%
'''
similar to training data except
  -without start and end positions
  -simplified offset mapping
  -uses example ids
'''
def preprocess_validation_examples(examples):
    questions = [q.strip() for q in examples["question"]]
    inputs = tokenizer(
        questions,
        examples["context"],
        max_length=max_length,
        truncation="only_second",
        stride=stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    sample_map = inputs.pop("overflow_to_sample_mapping")
    example_ids = []

    for i in range(len(inputs["input_ids"])):
        sample_idx = sample_map[i]
        example_ids.append(examples["id"][sample_idx])

        sequence_ids = inputs.sequence_ids(i)
        offset = inputs["offset_mapping"][i]
        inputs["offset_mapping"][i] = [
            o if sequence_ids[k] == 1 else None for k, o in enumerate(offset)
        ]

    inputs["example_id"] = example_ids
    return inputs

# %%
#use function to preprocess validation data
validation_dataset = raw_datasets["validation"].map(
    preprocess_validation_examples,
    batched=True,
    remove_columns=raw_datasets["validation"].column_names,
)
len(raw_datasets["validation"]), len(validation_dataset)
# Out:
# Map:   0%|          | 0/10570 [00:00<?, ? examples/s]
# (10570, 10822)

# %% [markdown]
# post processing

# %%
import evaluate
metric = evaluate.load("squad")
# Out:
# [codecarbon INFO @ 09:07:47] Energy consumed for RAM : 0.000071 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:07:47] Energy consumed for all GPUs : 0.000163 kWh. Total GPU Power : 11.978985735058462 W
# [codecarbon INFO @ 09:07:47] Energy consumed for all CPUs : 0.000344 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:07:47] 0.000578 kWh of electricity used since the beginning.

# %%
from tqdm.auto import tqdm
import collections
import numpy as np

n_best = 20
max_answer_length = 30
predicted_answers = []

def get_example(index):
    return tokenized_datasets["test"][index]["text"]

def compute_metrics(start_logits, end_logits, features, examples):
    experiment = comet_ml.get_global_experiment()
    example_to_features = collections.defaultdict(list)

    for idx, feature in enumerate(features):
        example_to_features[feature["example_id"]].append(idx)

    predicted_answers = []

    for example in tqdm(examples):
        example_id = example["id"]
        context = example["context"]
        answers = []

        # Loop through all features associated with that example
        for feature_index in example_to_features[example_id]:
            start_logit = start_logits[feature_index]
            end_logit = end_logits[feature_index]
            offsets = features[feature_index]["offset_mapping"]

            start_indexes = np.argsort(start_logit)[-1 : -n_best - 1 : -1].tolist()
            end_indexes = np.argsort(end_logit)[-1 : -n_best - 1 : -1].tolist()
            for start_index in start_indexes:
                for end_index in end_indexes:
                    # Skip answers that are not fully in the context
                    if offsets[start_index] is None or offsets[end_index] is None:
                        continue
                    # Skip answers with a length that is either < 0 or > max_answer_length
                    if (
                        end_index < start_index
                        or end_index - start_index + 1 > max_answer_length
                    ):
                        continue

                    answer = {
                        "text": context[offsets[start_index][0] : offsets[end_index][1]],
                        "logit_score": start_logit[start_index] + end_logit[end_index],
                    }
                    answers.append(answer)

        # Select the answer with the best score
        if len(answers) > 0:
            best_answer = max(answers, key=lambda x: x["logit_score"])
            predicted_answers.append(
                {"id": example_id, "prediction_text": best_answer["text"]}
            )
        else:
            predicted_answers.append({"id": example_id, "prediction_text": ""})

    theoretical_answers = [{"id": ex["id"], "answers": ex["answers"]} for ex in examples
    ]
    metric_result = metric.compute(predictions=predicted_answers, references=theoretical_answers)
    if experiment:
        #experiment.set_epoch(epoch)
        experiment.log_metric("f1", metric_result['f1'])
        experiment.log_metric("exact_match", metric_result['exact_match'])
    return metric_result

# %%
from transformers import AutoModelForQuestionAnswering
model = AutoModelForQuestionAnswering.from_pretrained(model_checkpoint)
# Out:
# model.safetensors:   0%|          | 0.00/263M [00:00<?, ?B/s]
# [codecarbon INFO @ 09:08:02] Energy consumed for RAM : 0.000095 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:08:02] Energy consumed for all GPUs : 0.000267 kWh. Total GPU Power : 24.937828347560743 W
# [codecarbon INFO @ 09:08:02] Energy consumed for all CPUs : 0.000461 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:08:02] 0.000823 kWh of electricity used since the beginning.
# Some weights of DistilBertForQuestionAnswering were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import transformers
from transformers import TrainingArguments
import accelerate

# %env COMET_MODE=ONLINE
# %env COMET_LOG_ASSETS=TRUE

args = TrainingArguments(
    "distilbert-finetuned-squad",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_steps=100,
    fp16=True,
    push_to_hub=True,
    report_to=["comet_ml"],
    logging_strategy="epoch",
    seed=42,
    load_best_model_at_end=False,
    save_total_limit=1,
)
# Out:
# env: COMET_MODE=ONLINE
# env: COMET_LOG_ASSETS=TRUE

# %%
from transformers import Trainer
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=validation_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:436: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False)
#   warnings.warn(
# [codecarbon INFO @ 09:08:06] Energy consumed for RAM : 0.000101 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:08:06] Energy consumed for all GPUs : 0.000298 kWh. Total GPU Power : 32.16485616275738 W
# [codecarbon INFO @ 09:08:06] Energy consumed for all CPUs : 0.000488 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:08:06] 0.000887 kWh of electricity used since the beginning.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : net_reef_1414
# COMET INFO:     url                   : https://www.comet.com/noushsuon/comet-bert-experiment/1d7f505c6812447ab1f62ba2cdd8fdad
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 1 (853 bytes)
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# [codecarbon INFO @ 09:08:08] [setup] RAM Tracking...
# [codecarbon INFO @ 09:08:08] [setup] GPU Tracking...
# [codecarbon INFO @ 09:08:08] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 09:08:08] [setup] CPU Tracking...
# [codecarbon WARNING @ 09:08:08] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 09:08:09] CPU Model on constant consumption mode: 13th Gen Intel(R) Core(TM) i9-13950HX
# [codecarbon INFO @ 09:08:09] >>> Tracker's metadata:
# [codecarbon INFO @ 09:08:09]   Platform system: Linux-5.15.133.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# [codecarbon INFO @ 09:08:09]   Python version: 3.10.12
# [codecarbon INFO @ 09:08:09]   CodeCarbon version: 2.3.5
# [codecarbon INFO @ 09:08:09]   Available RAM : 15.439 GB
# [codecarbon INFO @ 09:08:09]   CPU count: 32
# [codecarbon INFO @ 09:08:09]   CPU model: 13th Gen Intel(R) Core(TM) i9-13950HX
# [codecarbon INFO @ 09:08:09]   GPU count: 1
# [codecarbon INFO @ 09:08:09]   GPU model: 1 x NVIDIA GeForce RTX 4090 Laptop GPU
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/noushsuon/comet-bert-experiment/fa8cefe31b5e49669b61c56da4aef02f
#
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='33276' max='33276' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [33276/33276 29:57, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.489700</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.902200</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.659100</td>
#       <td>No log</td>
#     </tr>
#   </tbody>
# </table><p>
# [codecarbon INFO @ 09:08:25] Energy consumed for RAM : 0.000024 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:08:25] Energy consumed for all GPUs : 0.000444 kWh. Total GPU Power : 106.56462750138967 W
# [codecarbon INFO @ 09:08:25] Energy consumed for all CPUs : 0.000115 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:08:25] 0.000583 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:08:40] Energy consumed for RAM : 0.000048 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:08:40] Energy consumed for all GPUs : 0.000915 kWh. Total GPU Power : 113.0889640886433 W
# [codecarbon INFO @ 09:08:40] Energy consumed for all CPUs : 0.000229 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:08:40] 0.001192 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:08:55] Energy consumed for RAM : 0.000072 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:08:55] Energy consumed for all GPUs : 0.001402 kWh. Total GPU Power : 116.81034145380647 W
# [codecarbon INFO @ 09:08:55] Energy consumed for all CPUs : 0.000344 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:08:55] 0.001818 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:09:10] Energy consumed for RAM : 0.000096 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:09:10] Energy consumed for all GPUs : 0.001889 kWh. Total GPU Power : 117.00605603250104 W
# [codecarbon INFO @ 09:09:10] Energy consumed for all CPUs : 0.000458 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:09:10] 0.002444 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:09:25] Energy consumed for RAM : 0.000121 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:09:25] Energy consumed for all GPUs : 0.002372 kWh. Total GPU Power : 115.9534629211516 W
# [codecarbon INFO @ 09:09:25] Energy consumed for all CPUs : 0.000573 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:09:25] 0.003065 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:09:40] Energy consumed for RAM : 0.000145 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:09:40] Energy consumed for all GPUs : 0.002859 kWh. Total GPU Power : 116.96269267010871 W
# [codecarbon INFO @ 09:09:40] Energy consumed for all CPUs : 0.000687 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:09:40] 0.003691 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:09:55] Energy consumed for RAM : 0.000169 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:09:55] Energy consumed for all GPUs : 0.003341 kWh. Total GPU Power : 115.76448548211337 W
# [codecarbon INFO @ 09:09:55] Energy consumed for all CPUs : 0.000802 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:09:55] 0.004312 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:10:10] Energy consumed for RAM : 0.000193 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:10:10] Energy consumed for all GPUs : 0.003823 kWh. Total GPU Power : 115.78709227097632 W
# [codecarbon INFO @ 09:10:10] Energy consumed for all CPUs : 0.000917 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:10:10] 0.004933 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:10:25] Energy consumed for RAM : 0.000217 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:10:25] Energy consumed for all GPUs : 0.004295 kWh. Total GPU Power : 113.18716955867178 W
# [codecarbon INFO @ 09:10:25] Energy consumed for all CPUs : 0.001031 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:10:25] 0.005543 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:10:40] Energy consumed for RAM : 0.000241 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:10:40] Energy consumed for all GPUs : 0.004781 kWh. Total GPU Power : 116.66455522352669 W
# [codecarbon INFO @ 09:10:40] Energy consumed for all CPUs : 0.001146 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:10:40] 0.006168 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:10:55] Energy consumed for RAM : 0.000265 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:10:55] Energy consumed for all GPUs : 0.005263 kWh. Total GPU Power : 115.84216940685872 W
# [codecarbon INFO @ 09:10:55] Energy consumed for all CPUs : 0.001260 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:10:55] 0.006789 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:11:10] Energy consumed for RAM : 0.000289 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:11:10] Energy consumed for all GPUs : 0.005749 kWh. Total GPU Power : 116.7593397222396 W
# [codecarbon INFO @ 09:11:10] Energy consumed for all CPUs : 0.001375 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:11:10] 0.007414 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:11:25] Energy consumed for RAM : 0.000313 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:11:25] Energy consumed for all GPUs : 0.006235 kWh. Total GPU Power : 116.54929081488974 W
# [codecarbon INFO @ 09:11:25] Energy consumed for all CPUs : 0.001489 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:11:25] 0.008038 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:11:40] Energy consumed for RAM : 0.000338 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:11:40] Energy consumed for all GPUs : 0.006715 kWh. Total GPU Power : 115.34096912043593 W
# [codecarbon INFO @ 09:11:40] Energy consumed for all CPUs : 0.001604 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:11:40] 0.008657 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:11:55] Energy consumed for RAM : 0.000362 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:11:55] Energy consumed for all GPUs : 0.007201 kWh. Total GPU Power : 116.59439214191599 W
# [codecarbon INFO @ 09:11:55] Energy consumed for all CPUs : 0.001719 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:11:55] 0.009281 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:12:10] Energy consumed for RAM : 0.000386 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:12:10] Energy consumed for all GPUs : 0.007683 kWh. Total GPU Power : 115.6766291049349 W
# [codecarbon INFO @ 09:12:10] Energy consumed for all CPUs : 0.001833 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:12:10] 0.009902 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:12:25] Energy consumed for RAM : 0.000410 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:12:25] Energy consumed for all GPUs : 0.008169 kWh. Total GPU Power : 116.7729669624942 W
# [codecarbon INFO @ 09:12:25] Energy consumed for all CPUs : 0.001948 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:12:25] 0.010526 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:12:40] Energy consumed for RAM : 0.000434 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:12:40] Energy consumed for all GPUs : 0.008652 kWh. Total GPU Power : 115.90938565203486 W
# [codecarbon INFO @ 09:12:40] Energy consumed for all CPUs : 0.002062 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:12:40] 0.011148 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:12:55] Energy consumed for RAM : 0.000458 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:12:55] Energy consumed for all GPUs : 0.009137 kWh. Total GPU Power : 116.48897195544787 W
# [codecarbon INFO @ 09:12:55] Energy consumed for all CPUs : 0.002177 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:12:55] 0.011772 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:13:10] Energy consumed for RAM : 0.000482 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:13:10] Energy consumed for all GPUs : 0.009620 kWh. Total GPU Power : 116.02591720328046 W
# [codecarbon INFO @ 09:13:10] Energy consumed for all CPUs : 0.002291 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:13:10] 0.012394 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:13:25] Energy consumed for RAM : 0.000506 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:13:25] Energy consumed for all GPUs : 0.010102 kWh. Total GPU Power : 115.69809188679594 W
# [codecarbon INFO @ 09:13:25] Energy consumed for all CPUs : 0.002406 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:13:25] 0.013014 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:13:40] Energy consumed for RAM : 0.000530 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:13:40] Energy consumed for all GPUs : 0.010591 kWh. Total GPU Power : 117.4367907410239 W
# [codecarbon INFO @ 09:13:40] Energy consumed for all CPUs : 0.002520 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:13:40] 0.013642 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:13:55] Energy consumed for RAM : 0.000555 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:13:55] Energy consumed for all GPUs : 0.011074 kWh. Total GPU Power : 115.92561962083975 W
# [codecarbon INFO @ 09:13:55] Energy consumed for all CPUs : 0.002635 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:13:55] 0.014264 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:14:10] Energy consumed for RAM : 0.000579 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:14:10] Energy consumed for all GPUs : 0.011559 kWh. Total GPU Power : 116.4321306508716 W
# [codecarbon INFO @ 09:14:10] Energy consumed for all CPUs : 0.002750 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:14:10] 0.014887 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:14:25] Energy consumed for RAM : 0.000603 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:14:25] Energy consumed for all GPUs : 0.012044 kWh. Total GPU Power : 116.34265211064192 W
# [codecarbon INFO @ 09:14:25] Energy consumed for all CPUs : 0.002864 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:14:25] 0.015510 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:14:40] Energy consumed for RAM : 0.000627 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:14:40] Energy consumed for all GPUs : 0.012528 kWh. Total GPU Power : 116.41664885155008 W
# [codecarbon INFO @ 09:14:40] Energy consumed for all CPUs : 0.002979 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:14:40] 0.016134 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:14:55] Energy consumed for RAM : 0.000651 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:14:55] Energy consumed for all GPUs : 0.013009 kWh. Total GPU Power : 115.26333301042747 W
# [codecarbon INFO @ 09:14:55] Energy consumed for all CPUs : 0.003093 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:14:55] 0.016753 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:15:10] Energy consumed for RAM : 0.000675 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:15:10] Energy consumed for all GPUs : 0.013491 kWh. Total GPU Power : 115.82168822277832 W
# [codecarbon INFO @ 09:15:10] Energy consumed for all CPUs : 0.003208 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:15:10] 0.017374 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:15:25] Energy consumed for RAM : 0.000699 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:15:25] Energy consumed for all GPUs : 0.013973 kWh. Total GPU Power : 115.82959954186903 W
# [codecarbon INFO @ 09:15:25] Energy consumed for all CPUs : 0.003322 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:15:25] 0.017995 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:15:40] Energy consumed for RAM : 0.000723 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:15:40] Energy consumed for all GPUs : 0.014462 kWh. Total GPU Power : 117.39890365021273 W
# [codecarbon INFO @ 09:15:40] Energy consumed for all CPUs : 0.003437 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:15:40] 0.018623 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:15:55] Energy consumed for RAM : 0.000747 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:15:55] Energy consumed for all GPUs : 0.014941 kWh. Total GPU Power : 114.93888461785936 W
# [codecarbon INFO @ 09:15:55] Energy consumed for all CPUs : 0.003552 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:15:55] 0.019240 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:16:10] Energy consumed for RAM : 0.000772 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:16:10] Energy consumed for all GPUs : 0.015425 kWh. Total GPU Power : 116.08240460706692 W
# [codecarbon INFO @ 09:16:10] Energy consumed for all CPUs : 0.003666 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:16:10] 0.019862 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:16:25] Energy consumed for RAM : 0.000796 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:16:25] Energy consumed for all GPUs : 0.015909 kWh. Total GPU Power : 116.33241816236135 W
# [codecarbon INFO @ 09:16:25] Energy consumed for all CPUs : 0.003781 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:16:25] 0.020486 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:16:40] Energy consumed for RAM : 0.000820 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:16:40] Energy consumed for all GPUs : 0.016387 kWh. Total GPU Power : 114.66375776306296 W
# [codecarbon INFO @ 09:16:40] Energy consumed for all CPUs : 0.003895 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:16:40] 0.021102 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:16:55] Energy consumed for RAM : 0.000844 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:16:55] Energy consumed for all GPUs : 0.016869 kWh. Total GPU Power : 115.90707299040558 W
# [codecarbon INFO @ 09:16:55] Energy consumed for all CPUs : 0.004010 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:16:55] 0.021723 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:17:10] Energy consumed for RAM : 0.000868 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:17:10] Energy consumed for all GPUs : 0.017356 kWh. Total GPU Power : 116.89873986046968 W
# [codecarbon INFO @ 09:17:10] Energy consumed for all CPUs : 0.004124 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:17:10] 0.022349 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:17:25] Energy consumed for RAM : 0.000892 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:17:25] Energy consumed for all GPUs : 0.017840 kWh. Total GPU Power : 116.1240132468751 W
# [codecarbon INFO @ 09:17:25] Energy consumed for all CPUs : 0.004239 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:17:25] 0.022971 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:17:40] Energy consumed for RAM : 0.000916 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:17:40] Energy consumed for all GPUs : 0.018311 kWh. Total GPU Power : 113.011557672395 W
# [codecarbon INFO @ 09:17:40] Energy consumed for all CPUs : 0.004354 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:17:40] 0.023580 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:17:55] Energy consumed for RAM : 0.000940 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:17:55] Energy consumed for all GPUs : 0.018743 kWh. Total GPU Power : 103.7726624559964 W
# [codecarbon INFO @ 09:17:55] Energy consumed for all CPUs : 0.004468 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:17:55] 0.024151 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:18:10] Energy consumed for RAM : 0.000964 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:18:10] Energy consumed for all GPUs : 0.019225 kWh. Total GPU Power : 115.77412161789913 W
# [codecarbon INFO @ 09:18:10] Energy consumed for all CPUs : 0.004583 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:18:10] 0.024772 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:18:25] Energy consumed for RAM : 0.000989 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:18:25] Energy consumed for all GPUs : 0.019712 kWh. Total GPU Power : 116.8319341596059 W
# [codecarbon INFO @ 09:18:25] Energy consumed for all CPUs : 0.004697 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:18:25] 0.025398 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:18:40] Energy consumed for RAM : 0.001013 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:18:40] Energy consumed for all GPUs : 0.020198 kWh. Total GPU Power : 116.65655952733849 W
# [codecarbon INFO @ 09:18:40] Energy consumed for all CPUs : 0.004812 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:18:40] 0.026022 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:18:55] Energy consumed for RAM : 0.001037 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:18:55] Energy consumed for all GPUs : 0.020684 kWh. Total GPU Power : 116.86855392832831 W
# [codecarbon INFO @ 09:18:55] Energy consumed for all CPUs : 0.004926 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:18:55] 0.026648 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:19:10] Energy consumed for RAM : 0.001061 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:19:10] Energy consumed for all GPUs : 0.021165 kWh. Total GPU Power : 115.48460391787621 W
# [codecarbon INFO @ 09:19:10] Energy consumed for all CPUs : 0.005041 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:19:10] 0.027267 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:19:25] Energy consumed for RAM : 0.001085 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:19:25] Energy consumed for all GPUs : 0.021646 kWh. Total GPU Power : 115.40317164651442 W
# [codecarbon INFO @ 09:19:25] Energy consumed for all CPUs : 0.005156 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:19:25] 0.027887 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:19:40] Energy consumed for RAM : 0.001109 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:19:40] Energy consumed for all GPUs : 0.022129 kWh. Total GPU Power : 115.97390671828644 W
# [codecarbon INFO @ 09:19:40] Energy consumed for all CPUs : 0.005270 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:19:40] 0.028508 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:19:55] Energy consumed for RAM : 0.001133 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:19:55] Energy consumed for all GPUs : 0.022612 kWh. Total GPU Power : 115.93372453066434 W
# [codecarbon INFO @ 09:19:55] Energy consumed for all CPUs : 0.005385 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:19:55] 0.029130 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:20:10] Energy consumed for RAM : 0.001157 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:20:10] Energy consumed for all GPUs : 0.023094 kWh. Total GPU Power : 115.61828269525942 W
# [codecarbon INFO @ 09:20:10] Energy consumed for all CPUs : 0.005499 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:20:10] 0.029750 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:20:25] Energy consumed for RAM : 0.001181 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:20:25] Energy consumed for all GPUs : 0.023579 kWh. Total GPU Power : 116.49545990326641 W
# [codecarbon INFO @ 09:20:25] Energy consumed for all CPUs : 0.005614 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:20:25] 0.030374 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:20:40] Energy consumed for RAM : 0.001206 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:20:40] Energy consumed for all GPUs : 0.024062 kWh. Total GPU Power : 116.00545367531072 W
# [codecarbon INFO @ 09:20:40] Energy consumed for all CPUs : 0.005728 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:20:40] 0.030996 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:20:55] Energy consumed for RAM : 0.001230 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:20:55] Energy consumed for all GPUs : 0.024545 kWh. Total GPU Power : 116.01908287008959 W
# [codecarbon INFO @ 09:20:55] Energy consumed for all CPUs : 0.005843 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:20:55] 0.031618 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:21:10] Energy consumed for RAM : 0.001254 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:21:10] Energy consumed for all GPUs : 0.025028 kWh. Total GPU Power : 115.79564417962891 W
# [codecarbon INFO @ 09:21:10] Energy consumed for all CPUs : 0.005958 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:21:10] 0.032239 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:21:25] Energy consumed for RAM : 0.001278 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:21:25] Energy consumed for all GPUs : 0.025514 kWh. Total GPU Power : 116.75201933361426 W
# [codecarbon INFO @ 09:21:25] Energy consumed for all CPUs : 0.006072 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:21:25] 0.032864 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:21:40] Energy consumed for RAM : 0.001302 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:21:40] Energy consumed for all GPUs : 0.025993 kWh. Total GPU Power : 115.15414252549327 W
# [codecarbon INFO @ 09:21:40] Energy consumed for all CPUs : 0.006187 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:21:40] 0.033482 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:21:55] Energy consumed for RAM : 0.001326 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:21:55] Energy consumed for all GPUs : 0.026482 kWh. Total GPU Power : 117.31555547832188 W
# [codecarbon INFO @ 09:21:55] Energy consumed for all CPUs : 0.006301 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:21:55] 0.034109 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:22:10] Energy consumed for RAM : 0.001350 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:22:10] Energy consumed for all GPUs : 0.026964 kWh. Total GPU Power : 115.7298209589231 W
# [codecarbon INFO @ 09:22:10] Energy consumed for all CPUs : 0.006416 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:22:10] 0.034730 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:22:25] Energy consumed for RAM : 0.001374 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:22:25] Energy consumed for all GPUs : 0.027450 kWh. Total GPU Power : 116.830103847944 W
# [codecarbon INFO @ 09:22:25] Energy consumed for all CPUs : 0.006530 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:22:25] 0.035355 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:22:40] Energy consumed for RAM : 0.001398 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:22:40] Energy consumed for all GPUs : 0.027940 kWh. Total GPU Power : 117.65100665932344 W
# [codecarbon INFO @ 09:22:40] Energy consumed for all CPUs : 0.006645 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:22:40] 0.035984 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:22:55] Energy consumed for RAM : 0.001423 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:22:55] Energy consumed for all GPUs : 0.028421 kWh. Total GPU Power : 115.3940816265688 W
# [codecarbon INFO @ 09:22:55] Energy consumed for all CPUs : 0.006760 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:22:55] 0.036603 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:23:10] Energy consumed for RAM : 0.001447 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:23:10] Energy consumed for all GPUs : 0.028909 kWh. Total GPU Power : 117.24886420121993 W
# [codecarbon INFO @ 09:23:10] Energy consumed for all CPUs : 0.006874 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:23:10] 0.037230 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:23:25] Energy consumed for RAM : 0.001471 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:23:25] Energy consumed for all GPUs : 0.029390 kWh. Total GPU Power : 115.4507563885675 W
# [codecarbon INFO @ 09:23:25] Energy consumed for all CPUs : 0.006989 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:23:25] 0.037850 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:23:40] Energy consumed for RAM : 0.001495 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:23:40] Energy consumed for all GPUs : 0.029872 kWh. Total GPU Power : 115.68028910781551 W
# [codecarbon INFO @ 09:23:40] Energy consumed for all CPUs : 0.007103 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:23:40] 0.038470 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:23:55] Energy consumed for RAM : 0.001519 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:23:55] Energy consumed for all GPUs : 0.030357 kWh. Total GPU Power : 116.4462718227365 W
# [codecarbon INFO @ 09:23:55] Energy consumed for all CPUs : 0.007218 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:23:55] 0.039094 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:24:10] Energy consumed for RAM : 0.001543 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:24:10] Energy consumed for all GPUs : 0.030843 kWh. Total GPU Power : 116.52894354109371 W
# [codecarbon INFO @ 09:24:10] Energy consumed for all CPUs : 0.007332 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:24:10] 0.039718 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:24:25] Energy consumed for RAM : 0.001567 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:24:25] Energy consumed for all GPUs : 0.031327 kWh. Total GPU Power : 116.18048220685858 W
# [codecarbon INFO @ 09:24:25] Energy consumed for all CPUs : 0.007447 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:24:25] 0.040341 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:24:40] Energy consumed for RAM : 0.001591 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:24:40] Energy consumed for all GPUs : 0.031809 kWh. Total GPU Power : 115.74820673112067 W
# [codecarbon INFO @ 09:24:40] Energy consumed for all CPUs : 0.007561 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:24:40] 0.040962 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:24:55] Energy consumed for RAM : 0.001615 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:24:55] Energy consumed for all GPUs : 0.032294 kWh. Total GPU Power : 116.46022687909128 W
# [codecarbon INFO @ 09:24:55] Energy consumed for all CPUs : 0.007676 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:24:55] 0.041585 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:25:10] Energy consumed for RAM : 0.001640 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:25:10] Energy consumed for all GPUs : 0.032779 kWh. Total GPU Power : 116.5548185346176 W
# [codecarbon INFO @ 09:25:10] Energy consumed for all CPUs : 0.007791 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:25:10] 0.042210 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:25:25] Energy consumed for RAM : 0.001664 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:25:25] Energy consumed for all GPUs : 0.033269 kWh. Total GPU Power : 117.59932512071946 W
# [codecarbon INFO @ 09:25:25] Energy consumed for all CPUs : 0.007905 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:25:25] 0.042838 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:25:40] Energy consumed for RAM : 0.001688 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:25:40] Energy consumed for all GPUs : 0.033754 kWh. Total GPU Power : 116.35863412153266 W
# [codecarbon INFO @ 09:25:40] Energy consumed for all CPUs : 0.008020 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:25:40] 0.043462 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:25:55] Energy consumed for RAM : 0.001712 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:25:55] Energy consumed for all GPUs : 0.034242 kWh. Total GPU Power : 117.24542298399317 W
# [codecarbon INFO @ 09:25:55] Energy consumed for all CPUs : 0.008134 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:25:55] 0.044089 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:26:10] Energy consumed for RAM : 0.001736 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:26:10] Energy consumed for all GPUs : 0.034725 kWh. Total GPU Power : 115.97993073669817 W
# [codecarbon INFO @ 09:26:10] Energy consumed for all CPUs : 0.008249 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:26:10] 0.044710 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:26:25] Energy consumed for RAM : 0.001760 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:26:25] Energy consumed for all GPUs : 0.035212 kWh. Total GPU Power : 116.80659711056472 W
# [codecarbon INFO @ 09:26:25] Energy consumed for all CPUs : 0.008363 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:26:25] 0.045336 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:26:40] Energy consumed for RAM : 0.001784 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:26:40] Energy consumed for all GPUs : 0.035697 kWh. Total GPU Power : 116.52113240547467 W
# [codecarbon INFO @ 09:26:40] Energy consumed for all CPUs : 0.008478 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:26:40] 0.045960 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:26:55] Energy consumed for RAM : 0.001808 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:26:55] Energy consumed for all GPUs : 0.036183 kWh. Total GPU Power : 116.59623859256196 W
# [codecarbon INFO @ 09:26:55] Energy consumed for all CPUs : 0.008593 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:26:55] 0.046584 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:27:10] Energy consumed for RAM : 0.001833 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:27:10] Energy consumed for all GPUs : 0.036652 kWh. Total GPU Power : 112.60754801174588 W
# [codecarbon INFO @ 09:27:10] Energy consumed for all CPUs : 0.008707 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:27:10] 0.047192 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:27:25] Energy consumed for RAM : 0.001857 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:27:25] Energy consumed for all GPUs : 0.037108 kWh. Total GPU Power : 109.49061930173829 W
# [codecarbon INFO @ 09:27:25] Energy consumed for all CPUs : 0.008822 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:27:25] 0.047786 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:27:40] Energy consumed for RAM : 0.001881 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:27:40] Energy consumed for all GPUs : 0.037590 kWh. Total GPU Power : 115.65192491758727 W
# [codecarbon INFO @ 09:27:40] Energy consumed for all CPUs : 0.008936 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:27:40] 0.048407 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:27:55] Energy consumed for RAM : 0.001905 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:27:55] Energy consumed for all GPUs : 0.038069 kWh. Total GPU Power : 115.03082140275197 W
# [codecarbon INFO @ 09:27:55] Energy consumed for all CPUs : 0.009051 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:27:55] 0.049025 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:28:10] Energy consumed for RAM : 0.001929 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:28:10] Energy consumed for all GPUs : 0.038552 kWh. Total GPU Power : 115.90258956340385 W
# [codecarbon INFO @ 09:28:10] Energy consumed for all CPUs : 0.009165 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:28:10] 0.049646 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:28:25] Energy consumed for RAM : 0.001953 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:28:25] Energy consumed for all GPUs : 0.039031 kWh. Total GPU Power : 115.16722891954376 W
# [codecarbon INFO @ 09:28:25] Energy consumed for all CPUs : 0.009280 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:28:25] 0.050264 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:28:40] Energy consumed for RAM : 0.001977 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:28:40] Energy consumed for all GPUs : 0.039514 kWh. Total GPU Power : 115.89365791632049 W
# [codecarbon INFO @ 09:28:40] Energy consumed for all CPUs : 0.009395 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:28:40] 0.050886 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:28:55] Energy consumed for RAM : 0.002001 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:28:55] Energy consumed for all GPUs : 0.039999 kWh. Total GPU Power : 116.42803448264986 W
# [codecarbon INFO @ 09:28:55] Energy consumed for all CPUs : 0.009509 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:28:55] 0.051509 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:29:10] Energy consumed for RAM : 0.002025 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:29:10] Energy consumed for all GPUs : 0.040487 kWh. Total GPU Power : 117.2715601275411 W
# [codecarbon INFO @ 09:29:10] Energy consumed for all CPUs : 0.009624 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:29:10] 0.052136 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:29:25] Energy consumed for RAM : 0.002050 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:29:25] Energy consumed for all GPUs : 0.040970 kWh. Total GPU Power : 115.84633702146152 W
# [codecarbon INFO @ 09:29:25] Energy consumed for all CPUs : 0.009738 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:29:25] 0.052758 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:29:40] Energy consumed for RAM : 0.002074 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:29:40] Energy consumed for all GPUs : 0.041452 kWh. Total GPU Power : 115.69218298381831 W
# [codecarbon INFO @ 09:29:40] Energy consumed for all CPUs : 0.009853 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:29:40] 0.053378 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:29:55] Energy consumed for RAM : 0.002098 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:29:55] Energy consumed for all GPUs : 0.041941 kWh. Total GPU Power : 117.3905328349139 W
# [codecarbon INFO @ 09:29:55] Energy consumed for all CPUs : 0.009968 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:29:55] 0.054006 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:30:10] Energy consumed for RAM : 0.002122 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:30:10] Energy consumed for all GPUs : 0.042421 kWh. Total GPU Power : 115.34918897000144 W
# [codecarbon INFO @ 09:30:10] Energy consumed for all CPUs : 0.010082 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:30:10] 0.054625 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:30:25] Energy consumed for RAM : 0.002146 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:30:25] Energy consumed for all GPUs : 0.042906 kWh. Total GPU Power : 116.54642602818446 W
# [codecarbon INFO @ 09:30:25] Energy consumed for all CPUs : 0.010197 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:30:25] 0.055249 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:30:40] Energy consumed for RAM : 0.002170 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:30:40] Energy consumed for all GPUs : 0.043391 kWh. Total GPU Power : 116.3059676972674 W
# [codecarbon INFO @ 09:30:40] Energy consumed for all CPUs : 0.010311 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:30:40] 0.055872 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:30:55] Energy consumed for RAM : 0.002194 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:30:55] Energy consumed for all GPUs : 0.043874 kWh. Total GPU Power : 115.93323967285352 W
# [codecarbon INFO @ 09:30:55] Energy consumed for all CPUs : 0.010426 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:30:55] 0.056493 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:31:10] Energy consumed for RAM : 0.002218 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:31:10] Energy consumed for all GPUs : 0.044357 kWh. Total GPU Power : 115.95602050504249 W
# [codecarbon INFO @ 09:31:10] Energy consumed for all CPUs : 0.010540 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:31:10] 0.057115 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:31:25] Energy consumed for RAM : 0.002242 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:31:25] Energy consumed for all GPUs : 0.044840 kWh. Total GPU Power : 116.01109264589945 W
# [codecarbon INFO @ 09:31:25] Energy consumed for all CPUs : 0.010655 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:31:25] 0.057737 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:31:40] Energy consumed for RAM : 0.002267 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:31:40] Energy consumed for all GPUs : 0.045325 kWh. Total GPU Power : 116.62179237633319 W
# [codecarbon INFO @ 09:31:40] Energy consumed for all CPUs : 0.010769 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:31:40] 0.058361 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:31:55] Energy consumed for RAM : 0.002291 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:31:55] Energy consumed for all GPUs : 0.045810 kWh. Total GPU Power : 116.4715434307891 W
# [codecarbon INFO @ 09:31:55] Energy consumed for all CPUs : 0.010884 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:31:55] 0.058985 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:32:10] Energy consumed for RAM : 0.002315 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:32:10] Energy consumed for all GPUs : 0.046296 kWh. Total GPU Power : 116.56323625690207 W
# [codecarbon INFO @ 09:32:10] Energy consumed for all CPUs : 0.010999 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:32:10] 0.059609 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:32:25] Energy consumed for RAM : 0.002339 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:32:25] Energy consumed for all GPUs : 0.046777 kWh. Total GPU Power : 115.59921933360616 W
# [codecarbon INFO @ 09:32:25] Energy consumed for all CPUs : 0.011113 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:32:25] 0.060229 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:32:40] Energy consumed for RAM : 0.002363 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:32:40] Energy consumed for all GPUs : 0.047264 kWh. Total GPU Power : 116.89285996715557 W
# [codecarbon INFO @ 09:32:40] Energy consumed for all CPUs : 0.011228 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:32:40] 0.060855 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:32:55] Energy consumed for RAM : 0.002387 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:32:55] Energy consumed for all GPUs : 0.047748 kWh. Total GPU Power : 116.15592081208793 W
# [codecarbon INFO @ 09:32:55] Energy consumed for all CPUs : 0.011342 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:32:55] 0.061477 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:33:10] Energy consumed for RAM : 0.002411 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:33:10] Energy consumed for all GPUs : 0.048230 kWh. Total GPU Power : 115.65880957034732 W
# [codecarbon INFO @ 09:33:10] Energy consumed for all CPUs : 0.011457 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:33:10] 0.062098 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:33:25] Energy consumed for RAM : 0.002435 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:33:25] Energy consumed for all GPUs : 0.048713 kWh. Total GPU Power : 116.1360200007794 W
# [codecarbon INFO @ 09:33:25] Energy consumed for all CPUs : 0.011571 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:33:25] 0.062720 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:33:40] Energy consumed for RAM : 0.002459 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:33:40] Energy consumed for all GPUs : 0.049195 kWh. Total GPU Power : 115.72719024737663 W
# [codecarbon INFO @ 09:33:40] Energy consumed for all CPUs : 0.011686 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:33:40] 0.063341 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:33:55] Energy consumed for RAM : 0.002484 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:33:55] Energy consumed for all GPUs : 0.049675 kWh. Total GPU Power : 115.07062093352225 W
# [codecarbon INFO @ 09:33:55] Energy consumed for all CPUs : 0.011801 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:33:55] 0.063959 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:34:10] Energy consumed for RAM : 0.002508 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:34:10] Energy consumed for all GPUs : 0.050160 kWh. Total GPU Power : 116.4502878804696 W
# [codecarbon INFO @ 09:34:10] Energy consumed for all CPUs : 0.011915 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:34:10] 0.064582 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:34:25] Energy consumed for RAM : 0.002532 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:34:25] Energy consumed for all GPUs : 0.050641 kWh. Total GPU Power : 115.52808836771715 W
# [codecarbon INFO @ 09:34:25] Energy consumed for all CPUs : 0.012030 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:34:25] 0.065202 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:34:40] Energy consumed for RAM : 0.002556 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:34:40] Energy consumed for all GPUs : 0.051123 kWh. Total GPU Power : 115.65842503641016 W
# [codecarbon INFO @ 09:34:40] Energy consumed for all CPUs : 0.012144 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:34:40] 0.065823 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:34:55] Energy consumed for RAM : 0.002580 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:34:55] Energy consumed for all GPUs : 0.051607 kWh. Total GPU Power : 116.21164223261852 W
# [codecarbon INFO @ 09:34:55] Energy consumed for all CPUs : 0.012259 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:34:55] 0.066446 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:35:10] Energy consumed for RAM : 0.002604 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:35:10] Energy consumed for all GPUs : 0.052090 kWh. Total GPU Power : 116.07877385612352 W
# [codecarbon INFO @ 09:35:10] Energy consumed for all CPUs : 0.012373 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:35:10] 0.067068 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:35:25] Energy consumed for RAM : 0.002628 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:35:25] Energy consumed for all GPUs : 0.052573 kWh. Total GPU Power : 115.81103350237633 W
# [codecarbon INFO @ 09:35:25] Energy consumed for all CPUs : 0.012488 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:35:25] 0.067689 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:35:40] Energy consumed for RAM : 0.002652 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:35:40] Energy consumed for all GPUs : 0.053054 kWh. Total GPU Power : 115.43925801279711 W
# [codecarbon INFO @ 09:35:40] Energy consumed for all CPUs : 0.012603 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:35:40] 0.068308 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:35:55] Energy consumed for RAM : 0.002676 kWh. RAM Power : 5.789747714996338 W
# [codecarbon INFO @ 09:35:55] Energy consumed for all GPUs : 0.053536 kWh. Total GPU Power : 115.73791682277013 W
# [codecarbon INFO @ 09:35:55] Energy consumed for all CPUs : 0.012717 kWh. Total CPU Power : 27.5 W
# [codecarbon INFO @ 09:35:55] 0.068929 kWh of electricity used since the beginning.
# [codecarbon INFO @ 09:36:10] Energy consumed for RAM : 0.002701 kWh. RAM Power : 5.789747714996338 W
# ...
# COMET INFO:     url                   : https://www.comet.com/noushsuon/comet-bert-experiment/fa8cefe31b5e49669b61c56da4aef02f
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     epoch [7]                   : (1.0, 3.0)
# COMET INFO:     eval_runtime [3]            : (18.0541, 18.2015)
# COMET INFO:     eval_samples_per_second [3] : (594.566, 599.42)
# COMET INFO:     eval_steps_per_second [3]   : (74.335, 74.941)
# COMET INFO:     learning_rate [3]           : (9.616540449573267e-09, 1.3338141603558122e-05)
# COMET INFO:     loss [3331]                 : (0.03457224369049072, 6.033203125)
# COMET INFO:     total_flos                  : 2.608361755366349e+16
# COMET INFO:     train_loss                  : 1.016996313737754
# COMET INFO:     train_runtime               : 1733.878
# COMET INFO:     train_samples_per_second    : 153.521
# COMET INFO:     train_steps_per_second      : 19.192
# COMET INFO:   Parameters:
# COMET INFO:     args/_n_gpu                             : 1
# COMET INFO:     args/_no_sync_in_gradient_accumulation  : True
# COMET INFO:     args/_setup_devices                     : cuda:0
# COMET INFO:     args/adafactor                          : False
# COMET INFO:     args/adam_beta1                         : 0.9
# COMET INFO:     args/adam_beta2                         : 0.999
# COMET INFO:     args/adam_epsilon                       : 1e-08
# COMET INFO:     args/auto_find_batch_size               : False
# COMET INFO:     args/bf16                               : False
# COMET INFO:     args/bf16_full_eval                     : False
# COMET INFO:     args/data_seed                          : None
# COMET INFO:     args/dataloader_drop_last               : False
# COMET INFO:     args/dataloader_num_workers             : 0
# COMET INFO:     args/dataloader_pin_memory              : True
# COMET INFO:     args/ddp_backend                        : None
# COMET INFO:     args/ddp_broadcast_buffers              : None
# COMET INFO:     args/ddp_bucket_cap_mb                  : None
# COMET INFO:     args/ddp_find_unused_parameters         : None
# COMET INFO:     args/ddp_timeout                        : 1800
# COMET INFO:     args/ddp_timeout_delta                  : 0:30:00
# COMET INFO:     args/debug                              : []
# COMET INFO:     args/deepspeed                          : None
# COMET INFO:     args/deepspeed_plugin                   : None
# COMET INFO:     args/default_optim                      : adamw_torch
# COMET INFO:     args/device                             : cuda:0
# COMET INFO:     args/disable_tqdm                       : False
# COMET INFO:     args/dispatch_batches                   : None
# COMET INFO:     args/distributed_state                  : Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# COMET INFO:     args/do_eval                            : True
# COMET INFO:     args/do_predict                         : False
# COMET INFO:     args/do_train                           : False
# COMET INFO:     args/eval_accumulation_steps            : None
# COMET INFO:     args/eval_batch_size                    : 8
# COMET INFO:     args/eval_delay                         : 0
# COMET INFO:     args/eval_steps                         : None
# COMET INFO:     args/evaluation_strategy                : IntervalStrategy.EPOCH
# COMET INFO:     args/fp16                               : True
# COMET INFO:     args/fp16_backend                       : auto
# COMET INFO:     args/fp16_full_eval                     : False
# COMET INFO:     args/fp16_opt_level                     : O1
# COMET INFO:     args/framework                          : pt
# COMET INFO:     args/fsdp                               : []
# COMET INFO:     args/fsdp_config                        : {'min_num_params': 0, 'xla': False, 'xla_fsdp_grad_ckpt': False}
# COMET INFO:     args/fsdp_min_num_params                : 0
# COMET INFO:     args/fsdp_transformer_layer_cls_to_wrap : None
# COMET INFO:     args/full_determinism                   : False
# COMET INFO:     args/gradient_accumulation_steps        : 1
# COMET INFO:     args/gradient_checkpointing             : False
# COMET INFO:     args/gradient_checkpointing_kwargs      : None
# COMET INFO:     args/greater_is_better                  : None
# COMET INFO:     args/group_by_length                    : False
# COMET INFO:     args/half_precision_backend             : auto
# COMET INFO:     args/hub_always_push                    : False
# COMET INFO:     args/hub_model_id                       : None
# COMET INFO:     args/hub_private_repo                   : False
# COMET INFO:     args/hub_strategy                       : HubStrategy.EVERY_SAVE
# COMET INFO:     args/hub_token                          : None
# COMET INFO:     args/ignore_data_skip                   : False
# COMET INFO:     args/include_inputs_for_metrics         : False
# COMET INFO:     args/include_tokens_per_second          : False
# COMET INFO:     args/jit_mode_eval                      : False
# COMET INFO:     args/label_names                        : None
# COMET INFO:     args/label_smoothing_factor             : 0.0
# COMET INFO:     args/learning_rate                      : 2e-05
# COMET INFO:     args/length_column_name                 : length
# COMET INFO:     args/load_best_model_at_end             : False
# COMET INFO:     args/local_process_index                : 0
# COMET INFO:     args/local_rank                         : 0
# COMET INFO:     args/log_level                          : passive
# COMET INFO:     args/log_level_replica                  : warning
# COMET INFO:     args/log_on_each_node                   : True
# COMET INFO:     args/logging_dir                        : distilbert-finetuned-squad/runs/Apr24_09-08-05_1812e4688817
# COMET INFO:     args/logging_first_step                 : False
# COMET INFO:     args/logging_nan_inf_filter             : True
# COMET INFO:     args/logging_steps                      : 100
# COMET INFO:     args/logging_strategy                   : IntervalStrategy.EPOCH
# COMET INFO:     args/lr_scheduler_type                  : SchedulerType.LINEAR
# COMET INFO:     args/max_grad_norm                      : 1.0
# COMET INFO:     args/max_steps                          : -1
# COMET INFO:     args/metric_for_best_model              : None
# COMET INFO:     args/mp_parameters                      :
# COMET INFO:     args/n_gpu                              : 1
# COMET INFO:     args/neftune_noise_alpha                : None
# COMET INFO:     args/no_cuda                            : False
# COMET INFO:     args/num_train_epochs                   : 3
# COMET INFO:     args/optim                              : OptimizerNames.ADAMW_TORCH
# COMET INFO:     args/optim_args                         : None
# COMET INFO:     args/output_dir                         : distilbert-finetuned-squad
# COMET INFO:     args/overwrite_output_dir               : False
# COMET INFO:     args/parallel_mode                      : ParallelMode.NOT_PARALLEL
# COMET INFO:     args/past_index                         : -1
# COMET INFO:     args/per_device_eval_batch_size         : 8
# COMET INFO:     args/per_device_train_batch_size        : 8
# COMET INFO:     args/per_gpu_eval_batch_size            : None
# COMET INFO:     args/per_gpu_train_batch_size           : None
# COMET INFO:     args/place_model_on_device              : True
# COMET INFO:     args/prediction_loss_only               : False
# COMET INFO:     args/process_index                      : 0
# COMET INFO:     args/push_to_hub                        : True
# COMET INFO:     args/push_to_hub_model_id               : None
# COMET INFO:     args/push_to_hub_organization           : None
# COMET INFO:     args/push_to_hub_token                  : None
# COMET INFO:     args/ray_scope                          : last
# COMET INFO:     args/remove_unused_columns              : True
# COMET INFO:     args/report_to                          : ['comet_ml']
# COMET INFO:     args/resume_from_checkpoint             : None
# COMET INFO:     args/run_name                           : distilbert-finetuned-squad
# COMET INFO:     args/save_on_each_node                  : False
# COMET INFO:     args/save_safetensors                   : True
# COMET INFO:     args/save_steps                         : 500
# COMET INFO:     args/save_strategy                      : IntervalStrategy.EPOCH
# COMET INFO:     args/save_total_limit                   : 1
# COMET INFO:     args/seed                               : 42
# COMET INFO:     args/should_log                         : True
# COMET INFO:     args/should_save                        : True
# COMET INFO:     args/skip_memory_metrics                : True
# COMET INFO:     args/split_batches                      : False
# COMET INFO:     args/tf32                               : None
# COMET INFO:     args/torch_compile                      : False
# COMET INFO:     args/torch_compile_backend              : None
# COMET INFO:     args/torch_compile_mode                 : None
# COMET INFO:     args/torchdynamo                        : None
# COMET INFO:     args/tpu_metrics_debug                  : False
# COMET INFO:     args/tpu_num_cores                      : None
# COMET INFO:     args/train_batch_size                   : 8
# COMET INFO:     args/use_cpu                            : False
# COMET INFO:     args/use_ipex                           : False
# COMET INFO:     args/use_legacy_prediction_loop         : False
# COMET INFO:     args/use_mps_device                     : False
# COMET INFO:     args/warmup_ratio                       : 0.0
# COMET INFO:     args/warmup_steps                       : 0
# COMET INFO:     args/weight_decay                       : 0.01
# COMET INFO:     args/world_size                         : 1
# COMET INFO:     config/_auto_class                      : None
# COMET INFO:     config/_commit_hash                     : 0dacbb01d604f8adeeb5b87c9339e485ac40d5c0
# COMET INFO:     config/_name_or_path                    : distilbert-base-cased
# COMET INFO:     config/activation                       : gelu
# COMET INFO:     config/add_cross_attention              : False
# COMET INFO:     config/architectures                    : ['DistilBertForMaskedLM']
# COMET INFO:     config/attention_dropout                : 0.1
# COMET INFO:     config/attribute_map                    : {'hidden_size': 'dim', 'num_attention_heads': 'n_heads', 'num_hidden_layers': 'n_layers'}
# COMET INFO:     config/bad_words_ids                    : None
# COMET INFO:     config/begin_suppress_tokens            : None
# COMET INFO:     config/bos_token_id                     : None
# COMET INFO:     config/chunk_size_feed_forward          : 0
# COMET INFO:     config/cross_attention_hidden_size      : None
# COMET INFO:     config/decoder_start_token_id           : None
# COMET INFO:     config/dim                              : 768
# COMET INFO:     config/diversity_penalty                : 0.0
# COMET INFO:     config/do_sample                        : False
# COMET INFO:     config/dropout                          : 0.1
# COMET INFO:     config/early_stopping                   : False
# COMET INFO:     config/encoder_no_repeat_ngram_size     : 0
# COMET INFO:     config/eos_token_id                     : None
# COMET INFO:     config/exponential_decay_length_penalty : None
# COMET INFO:     config/finetuning_task                  : None
# COMET INFO:     config/forced_bos_token_id              : None
# COMET INFO:     config/forced_eos_token_id              : None
# COMET INFO:     config/hidden_dim                       : 3072
# COMET INFO:     config/id2label                         : {0: 'LABEL_0', 1: 'LABEL_1'}
# COMET INFO:     config/initializer_range                : 0.02
# COMET INFO:     config/is_composition                   : False
# COMET INFO:     config/is_decoder                       : False
# COMET INFO:     config/is_encoder_decoder               : False
# COMET INFO:     config/label2id                         : {'LABEL_0': 0, 'LABEL_1': 1}
# COMET INFO:     config/length_penalty                   : 1.0
# COMET INFO:     config/max_length                       : 20
# COMET INFO:     config/max_position_embeddings          : 512
# COMET INFO:     config/min_length                       : 0
# COMET INFO:     config/model_type                       : distilbert
# COMET INFO:     config/n_heads                          : 12
# COMET INFO:     config/n_layers                         : 6
# COMET INFO:     config/name_or_path                     : distilbert-base-cased
# COMET INFO:     config/no_repeat_ngram_size             : 0
# COMET INFO:     config/num_beam_groups                  : 1
# COMET INFO:     config/num_beams                        : 1
# COMET INFO:     config/num_labels                       : 2
# COMET INFO:     config/num_return_sequences             : 1
# COMET INFO:     config/output_attentions                : False
# COMET INFO:     config/output_hidden_states             : False
# COMET INFO:     config/output_past                      : True
# COMET INFO:     config/output_scores                    : False
# COMET INFO:     config/pad_token_id                     : 0
# COMET INFO:     config/prefix                           : None
# COMET INFO:     config/problem_type                     : None
# COMET INFO:     config/pruned_heads                     : {}
# COMET INFO:     config/qa_dropout                       : 0.1
# COMET INFO:     config/remove_invalid_values            : False
# COMET INFO:     config/repetition_penalty               : 1.0
# COMET INFO:     config/return_dict                      : True
# COMET INFO:     config/return_dict_in_generate          : False
# COMET INFO:     config/sep_token_id                     : None
# COMET INFO:     config/seq_classif_dropout              : 0.2
# COMET INFO:     config/sinusoidal_pos_embds             : False
# COMET INFO:     config/suppress_tokens                  : None
# COMET INFO:     config/task_specific_params             : None
# COMET INFO:     config/temperature                      : 1.0
# COMET INFO:     config/tf_legacy_loss                   : False
# COMET INFO:     config/tie_encoder_decoder              : False
# COMET INFO:     config/tie_weights_                     : True
# COMET INFO:     config/tie_word_embeddings              : True
# COMET INFO:     config/tokenizer_class                  : None
# COMET INFO:     config/top_k                            : 50
# COMET INFO:     config/top_p                            : 1.0
# COMET INFO:     config/torch_dtype                      : None
# COMET INFO:     config/torchscript                      : False
# COMET INFO:     config/transformers_version             : None
# COMET INFO:     config/typical_p                        : 1.0
# COMET INFO:     config/use_bfloat16                     : False
# COMET INFO:     config/use_return_dict                  : True
# COMET INFO:     config/vocab_size                       : 28996
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 19 (996.58 MB)
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     model graph         : 1
# COMET INFO:     notebook            : 2
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET INFO: Please wait for assets to finish uploading (timeout is 10800 seconds)
# COMET INFO: Still uploading 21 file(s), remaining 996.56 MB/996.56 MB
# COMET INFO: Still uploading 3 asset(s), remaining 884.86 MB/994.86 MB, Throughput 7.44 MB/s, ETA ~119s
# COMET INFO: Still uploading 3 asset(s), remaining 604.86 MB/994.86 MB, Throughput 18.64 MB/s, ETA ~33s
# COMET INFO: Still uploading 2 asset(s), remaining 261.16 MB/746.16 MB, Throughput 22.88 MB/s, ETA ~12s
# COMET INFO: Still uploading 1 asset(s), remaining 62.46 MB/497.46 MB, Throughput 13.23 MB/s, ETA ~5s
# TrainOutput(global_step=33276, training_loss=1.016996313737754, metrics={'train_runtime': 1733.878, 'train_samples_per_second': 153.521, 'train_steps_per_second': 19.192, 'total_flos': 2.608361755366349e+16, 'train_loss': 1.016996313737754, 'epoch': 3.0})

# %%
predictions, _, _ = trainer.predict(validation_dataset)
start_logits, end_logits = predictions
compute_metrics(start_logits, end_logits, validation_dataset, raw_datasets["validation"])
# Out:
#   0%|          | 0/10570 [00:00<?, ?it/s]
# {'exact_match': 77.4550614947966, 'f1': 85.73340175391337}

# %%
cumulator.off()
cumulator.on()

# %%
cumulator.display_carbon_footprint()
# Out:
# ########
# Overall carbon footprint: 4.89e+00 gCO2eq
# ########
# Carbon footprint due to computations: 4.89e+00 gCO2eq
# Carbon footprint due to communications: 0.00e+00 gCO2eq
# This carbon footprint is equivalent to 1.39e-04 square meters of u.s. forests preserved from conversion to cropland in one year.

# %%
trainer.push_to_hub(commit_message="Training complete")
# Out:
# CommitInfo(commit_url='https://huggingface.co/noushsuon/distilbert-finetuned-squad/commit/ea8db5b182d904a96ffa37a1783f0344065ad7c2', commit_message='Training complete', commit_description='', oid='ea8db5b182d904a96ffa37a1783f0344065ad7c2', pr_url=None, pr_revision=None, pr_num=None)

# %%
from torch.utils.data import DataLoader
from transformers import default_data_collator

train_dataset.set_format("torch")
validation_set = validation_dataset.remove_columns(["example_id", "offset_mapping"])
validation_set.set_format("torch")

train_dataloader = DataLoader(
    train_dataset,
    shuffle=True,
    collate_fn=default_data_collator,
    batch_size=8,
)
eval_dataloader = DataLoader(
    validation_set, collate_fn=default_data_collator, batch_size=8
)

# %%
from torch.optim import AdamW

optimizer = AdamW(model.parameters(), lr=2e-5)

# %%
from accelerate import Accelerator

accelerator = Accelerator()
model, optimizer, train_dataloader, eval_dataloader = accelerator.prepare(
    model, optimizer, train_dataloader, eval_dataloader
)

# %%
from transformers import get_scheduler

num_train_epochs = 3
num_update_steps_per_epoch = len(train_dataloader)
num_training_steps = num_train_epochs * num_update_steps_per_epoch

lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=num_training_steps,
)

# %%
from huggingface_hub import Repository, get_full_repo_name
model_name = "distilbert-finetuned-squad"
repo_name = get_full_repo_name(model_name)
repo_name
# Out:
# 'noushsuon/distilbert-finetuned-squad'

# %%
from huggingface_hub import Repository
output_dir = "distilbert-finetuned-squad-accelerate" + model_checkpoint

repo = Repository(output_dir, clone_from=repo_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# Cloning https://huggingface.co/noushsuon/distilbert-finetuned-squad into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/noushsuon/distilbert-finetuned-squad into local empty directory.
# Download file model.safetensors:   0%|          | 3.45k/249M [00:00<?, ?B/s]
# Download file training_args.bin: 100%|##########| 4.49k/4.49k [00:00<?, ?B/s]
# Clean file training_args.bin:  22%|##2       | 1.00k/4.49k [00:00<?, ?B/s]
# Clean file model.safetensors:   0%|          | 1.00k/249M [00:00<?, ?B/s]

# %%
from tqdm.auto import tqdm
import torch

progress_bar = tqdm(range(num_training_steps))

for epoch in range(num_train_epochs):
    # Training
    model.train()
    for step, batch in enumerate(train_dataloader):
        outputs = model(**batch)
        loss = outputs.loss
        accelerator.backward(loss)

        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)

    # Evaluation
    model.eval()
    start_logits = []
    end_logits = []
    accelerator.print("Evaluation!")
    for batch in tqdm(eval_dataloader):
        with torch.no_grad():
            outputs = model(**batch)

        start_logits.append(accelerator.gather(outputs.start_logits).cpu().numpy())
        end_logits.append(accelerator.gather(outputs.end_logits).cpu().numpy())

    start_logits = np.concatenate(start_logits)
    end_logits = np.concatenate(end_logits)
    start_logits = start_logits[: len(validation_dataset)]
    end_logits = end_logits[: len(validation_dataset)]

    metrics = compute_metrics(
        start_logits, end_logits, validation_dataset, raw_datasets["validation"]
    )

    for key, value in metrics.items():
        experiment.log_metric(key, value)

    print(f"epoch {epoch}:", metrics)

    # Save and upload
    accelerator.wait_for_everyone()
    unwrapped_model = accelerator.unwrap_model(model)
    unwrapped_model.save_pretrained(output_dir, save_function=accelerator.save)
    if accelerator.is_main_process:
        tokenizer.save_pretrained(output_dir)
        repo.push_to_hub(
            commit_message=f"Training in progress epoch {epoch}", blocking=False
        )
# Out:
#   0%|          | 0/33276 [00:00<?, ?it/s]
# Evaluation!
#   0%|          | 0/1353 [00:00<?, ?it/s]
#   0%|          | 0/10570 [00:00<?, ?it/s]
# epoch 0: {'exact_match': 75.600756859035, 'f1': 84.27080920765526}
# Evaluation!
#   0%|          | 0/1353 [00:00<?, ?it/s]
#   0%|          | 0/10570 [00:00<?, ?it/s]
# epoch 1: {'exact_match': 76.29139072847683, 'f1': 85.01808418996504}
# Evaluation!
#   0%|          | 0/1353 [00:00<?, ?it/s]
#   0%|          | 0/10570 [00:00<?, ?it/s]
# epoch 2: {'exact_match': 75.62913907284768, 'f1': 84.73481219170759}

# %%
accelerator.wait_for_everyone()
unwrapped_model = accelerator.unwrap_model(model)
unwrapped_model.save_pretrained(output_dir, save_function=accelerator.save)

# %%
experiment.end()

# %%
cumulator.off()
cumulator.display_carbon_footprint()
# Out:
# ########
# Overall carbon footprint: 9.37e+00 gCO2eq
# ########
# Carbon footprint due to computations: 9.37e+00 gCO2eq
# Carbon footprint due to communications: 0.00e+00 gCO2eq
# This carbon footprint is equivalent to 3.48e-03 liters of diesel consumed.
